# %%
## CODE IDEAS FOR HOMEWORK #3: SENTIMENT ANALYSIS
# DATA NEEDED: Two datasets of tweets, as follows: 
# The training set is an annotated corpus with sentiment related to Airline Services
# from the Kaggle competition website (https://www.kaggle.com/crowdflower/twitter-airline-sentiment)
# The test dataset is about Coronavirus and has no annotation
# the IEEE data portal (https://ieee-dataport.org/open-access/free-dataset-newsmessage-boardsblogs-about-coronavirus-4-month-data-52m-posts)
# the train dataset includes a column with labeling each tweet as 'positive,' 'negative' or 'neutral'
# the test set is an unlabeled data for the classifier to predict the right label
# DATASETS AVAILABLE IN THIS LINK:
# https://sumailsyr-my.sharepoint.com/:u:/g/personal/nepalomi_syr_edu/EeUvfYcoMMZOhY249JiTuBsBwt_ZMbOQwYp5howQ3drcOw?e=1OeGeJ

# We will use 'pandas', a panel (tabular) data Python library for manipulating tables
# more info: https://en.wikipedia.org/wiki/Pandas_(software)

import pandas as pd

#read_file = pd.read_csv ('inourtime.txt')
#read_file.to_csv ('inourtime.txt.csv', index=None)

# We'll use 'read_csv' to read our test file, sotred as csv 
test_set = pd.read_csv('aliceinwonderland.csv')
print(test_set[:20])
len(test_set)
# Out:
#                                                  text
# 0                                          CHAPTER I.
# 1                                Down the Rabbit-Hole
# 2   Alice was beginning to get very tired of sitti...
# 3   bank, and of having nothing to do: once or twi...
# 4   the book her sister was reading, but it had no...
# 5   conversations in it, and what is the use of a ...
# 6                 without pictures or conversations?
# 7   So she was considering in her own mind (as wel...
# 8   hot day made her feel very sleepy and stupid),...
# 9   making a daisy-chain would be worth the troubl...
# 10  picking the daisies, when suddenly a White Rab...
# 11                                      close by her.
# 12  There was nothing so _very_ remarkable in that...
# 13  so _very_ much out of the way to hear the Rabb...
# 14  dear! Oh dear! I shall be late! (when she tho...
# 15  it occurred to her that she ought to have wond...
# 16  time it all seemed quite natural); but when th...
# 17  watch out of its waistcoat-pocket_, and looked...
# 18  on, Alice started to her feet, for it flashed ...
# 19  had never before seen a rabbit with either a w...
# 2477

# %%
#using the Airline Services dataset for training on sentiment polarity
train_dataset = pd.read_csv('train_tweets_airlines.csv')
#displaying the dataset using pandas
display(len(train_dataset))
display(train_dataset.head(2))
# Out:
# 14640
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                        0.0  Virgin America
#
#   airline_sentiment_gold      name negativereason_gold  retweet_count  \
# 0                    NaN   cairdin                 NaN              0
# 1                    NaN  jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)

# %%
# Since this is social media data, we will have to add a few extra preprocessing steps
# First, let's remove  @ and # (Twitter platform affordances) from the training data
# We'll use regular expressions for that, creating a Function that we can use to pass the data through
# NOTE: you could add more regexes to clean noisy characters such as emoticons, numbers, etc
def remove_at(x):
    x = str(x).replace('@', '')
    x = str(x).replace('#', '')
    return x

# %%
#applyting the clearning function and visualizing the result
train_dataset['text'] = train_dataset['text'].apply(lambda x: remove_at(x))
display(len(train_dataset))
display(train_dataset['text'].head(5))
# Out:
# 14640
# 0                    VirginAmerica What dhepburn said.
# 1    VirginAmerica plus you've added commercials to...
# 2    VirginAmerica I didn't today... Must mean I ne...
# 3    VirginAmerica it's really aggressive to blast ...
# 4    VirginAmerica and it's a really big bad thing ...
# Name: text, dtype: object

# %%
# tokenizing using RegexTokenizer for tokenizing using specific regular expressions
# in our case, we eliminate Twitter's noise by picking up only alphabets and numbers
# indicated by the 'w', the regex alias for 'word'

import nltk

tokenizer = nltk.RegexpTokenizer('\w+')
doc = train_dataset['text'].apply(lambda x : tokenizer.tokenize(x))
display(len(doc))
display(doc.head(5))
# Out:
# 14640
# 0                [VirginAmerica, What, dhepburn, said]
# 1    [VirginAmerica, plus, you, ve, added, commerci...
# 2    [VirginAmerica, I, didn, t, today, Must, mean,...
# 3    [VirginAmerica, it, s, really, aggressive, to,...
# 4    [VirginAmerica, and, it, s, a, really, big, ba...
# Name: text, dtype: object

# %%
#EXPLORATORY ANAYSIS
#Checking if the dataset is balanced
#extracting types of labels from the 'airline_sentiment' column in the dataset
PosSentences = train_dataset[train_dataset['airline_sentiment'] == 'positive']
NegSentences = train_dataset[train_dataset['airline_sentiment'] == 'negative']
NeuSentences = train_dataset[train_dataset['airline_sentiment'] == 'neutral']

#grouping all labels to find out the count for each group
label_groups = train_dataset.groupby('airline_sentiment').size().reset_index(name='counts')
display(label_groups.head(5))
# Out:
#   airline_sentiment  counts
# 0          negative    9178
# 1           neutral    3099
# 2          positive    2363

# %%
#Visualizing label group data within training dataset
# NOTE that the dataset is unbalanced
# please come up with strategies to balance this dataset
# if not, explain how that affect your results
# if using unbalanced dataset, please provide MicroAverage evaluation scores from your classifier

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
ax = sns.barplot(x="airline_sentiment", y="counts", data=label_groups)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0)
ax.set_title(label="Sentiment Distribution")
plt.show()

# %%
#BEGGINING TO WORK ON THE CLASSIFICATION TASK
# extracting the tweet message and its asigned sentiment label
# we do this by creating a Python list
# our list will have the tweet's tokens and corresponding sentiments

# opening a list to store our data
docs = []

# iterating over the dataset and extracting the information sought
for i in range(0, len(train_dataset['airline_sentiment'])):
    # appending the info to the list
    docs.append((doc[i], train_dataset['airline_sentiment'][i]))

#printing the output for validation
docs[0]
# Out:
# (['VirginAmerica', 'What', 'dhepburn', 'said'], 'neutral')

# %%
    
# The dataset is sorted by sentiment label
# so we need to randomize it to avoid sampling biases 

#importing the random library
import random

#shuffling the documents
random.shuffle(docs)

# %%
#defining set of words that will be used for features
#we'll find the 2000 most common words and used them as an important feature of the whole corpus

all_words = [word for (sentance,category) in docs for word in sentance]
top_words = nltk.FreqDist(all_words)
most_common_words = top_words.most_common(2000)
word_features = [word for (word,count) in most_common_words]

# %%
#checking if we have the 2000 words we need
len(set(all_words))
# Out:
# 18042

# %%
#now we will use that list of most frequent words in the entire corpus
#to iterate over each sentence and check if any of those words are present
#in that way, we will see if this unigram corpus feature is present on that particular sentence
#using Boolean logic that matches values and returns 'True' or 'False'
#we do this by defining a Python "function," i.e.a piece of code writen to be reused
def document_features(document, word_features):
    document_words = set(document)
    #we open a Pytnon dictionary instead of a list
    features = {}
    for word in word_features:
        #checking if the word from word_features matches a word in the document
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %%
#now we apply the function to the document dataset
featuresets = [(document_features(d, word_features), c) for (d, c) in docs]

#we print the list of features matches for the first document ([0]) in the corpus
#we'll see a Python dictionary with the key being the feature word
#and the value being 'True' or 'False' according to that word being matched in the present document or not
#we'll se a lot of 'False' values because (of course) not all 2000 words will be on each sentence!
featuresets[0]
# Out:
# ({'contains(to)': True,
#   'contains(I)': False,
#   'contains(the)': False,
#   'contains(a)': False,
#   'contains(for)': True,
#   'contains(you)': False,
#   'contains(united)': False,
#   'contains(on)': True,
#   'contains(and)': False,
#   'contains(t)': True,
#   'contains(flight)': True,
#   'contains(my)': False,
#   'contains(USAirways)': False,
#   'contains(AmericanAir)': True,
#   'contains(is)': False,
#   'contains(in)': False,
#   'contains(SouthwestAir)': False,
#   'contains(JetBlue)': False,
#   'contains(of)': False,
#   'contains(it)': False,
#   'contains(me)': True,
#   'contains(that)': False,
#   'contains(have)': False,
#   'contains(your)': False,
#   'contains(was)': False,
#   'contains(s)': False,
#   'contains(with)': False,
#   'contains(at)': False,
#   'contains(not)': False,
#   'contains(can)': True,
#   'contains(get)': True,
#   'contains(co)': False,
#   'contains(be)': False,
#   'contains(from)': False,
#   'contains(this)': False,
#   'contains(http)': False,
#   'contains(no)': False,
#   'contains(but)': True,
#   'contains(Cancelled)': False,
#   'contains(are)': False,
#   'contains(we)': False,
#   'contains(an)': True,
#   'contains(service)': False,
#   'contains(2)': False,
#   'contains(now)': False,
#   'contains(do)': False,
#   'contains(been)': False,
#   'contains(time)': True,
#   'contains(so)': False,
#   'contains(just)': False,
#   'contains(Flight)': False,
#   'contains(help)': False,
#   'contains(up)': False,
#   'contains(m)': False,
#   'contains(out)': False,
#   'contains(customer)': False,
#   'contains(amp)': False,
#   'contains(will)': False,
#   'contains(hours)': False,
#   'contains(hold)': False,
#   'contains(they)': False,
#   'contains(flights)': False,
#   'contains(plane)': False,
#   'contains(all)': False,
#   'contains(there)': False,
#   'contains(when)': False,
#   'contains(what)': False,
#   'contains(Thanks)': False,
#   'contains(thanks)': False,
#   'contains(one)': False,
#   'contains(us)': False,
#   'contains(back)': False,
#   'contains(our)': False,
#   'contains(would)': False,
#   'contains(Flightled)': False,
#   'contains(if)': False,
#   'contains(delayed)': False,
#   'contains(call)': False,
#   'contains(VirginAmerica)': False,
#   'contains(about)': True,
#   'contains(still)': False,
#   'contains(ve)': False,
#   'contains(bag)': False,
#   'contains(gate)': False,
#   'contains(need)': False,
#   'contains(had)': False,
#   'contains(hour)': False,
#   'contains(or)': False,
#   'contains(has)': False,
#   'contains(as)': False,
#   'contains(how)': False,
#   'contains(why)': False,
#   'contains(got)': False,
#   'contains(Late)': False,
#   'contains(3)': False,
#   'contains(after)': False,
#   'contains(like)': False,
#   'contains(phone)': True,
#   'contains(don)': False,
#   'contains(today)': False,
#   'contains(You)': False,
#   'contains(airline)': False,
#   'contains(am)': False,
#   'contains(by)': False,
#   'contains(over)': False,
#   'contains(more)': False,
#   'contains(re)': False,
#   'contains(guys)': False,
#   'contains(fly)': False,
#   'contains(again)': False,
#   'contains(please)': False,
#   'contains(4)': False,
#   'contains(know)': False,
#   'contains(1)': False,
#   'contains(waiting)': False,
#   'contains(way)': False,
#   'contains(i)': False,
#   'contains(United)': False,
#   'contains(any)': False,
#   'contains(No)': False,
#   'contains(day)': False,
#   'contains(Can)': False,
#   'contains(change)': True,
#   'contains(wait)': False,
#   'contains(Thank)': False,
#   'contains(airport)': False,
#   'contains(It)': False,
#   'contains(because)': False,
#   'contains(trying)': False,
#   'contains(tomorrow)': False,
#   'contains(We)': False,
#   'contains(should)': False,
#   'contains(going)': False,
#   'contains(did)': False,
#   'contains(5)': False,
#   'contains(then)': False,
#   'contains(make)': False,
#   'contains(go)': False,
#   'contains(weather)': False,
#   'contains(flying)': False,
#   'contains(minutes)': False,
#   'contains(delay)': False,
#   'contains(only)': False,
#   'contains(home)': False,
#   'contains(off)': False,
#   'contains(check)': False,
#   'contains(last)': False,
#   'contains(here)': False,
#   'contains(people)': False,
#   'contains(even)': False,
#   'contains(thank)': False,
#   'contains(were)': False,
#   'contains(u)': False,
#   'contains(seat)': False,
#   'contains(bags)': False,
#   'contains(ll)': False,
#   'contains(w)': False,
#   'contains(take)': False,
#   'contains(great)': False,
#   'contains(want)': False,
#   'contains(told)': False,
#   'contains(What)': False,
#   'contains(luggage)': False,
#   'contains(them)': False,
#   'contains(ticket)': False,
#   'contains(agent)': False,
#   'contains(DM)': False,
#   'contains(never)': False,
#   'contains(good)': False,
#   'contains(than)': False,
#   'contains(see)': False,
#   'contains(due)': False,
#   'contains(number)': False,
#   'contains(work)': True,
#   'contains(getting)': False,
#   'contains(email)': True,
#   'contains(another)': False,
#   'contains(travel)': False,
#   'contains(first)': False,
#   'contains(could)': False,
#   'contains(really)': False,
#   'contains(someone)': False,
#   'contains(Flighted)': False,
#   'contains(hrs)': False,
#   'contains(days)': False,
#   'contains(lost)': False,
#   'contains(crew)': False,
#   'contains(ever)': False,
#   'contains(through)': False,
#   'contains(How)': False,
#   'contains(too)': False,
#   'contains(next)': False,
#   'contains(My)': False,
#   'contains(new)': False,
#   'contains(baggage)': False,
#   'contains(The)': False,
#   'contains(much)': False,
#   'contains(trip)': False,
#   'contains(This)': False,
#   'contains(response)': False,
#   'contains(before)': False,
#   'contains(very)': False,
#   'contains(their)': False,
#   'contains(AA)': False,
#   'contains(two)': False,
#   'contains(Just)': False,
#   'contains(let)': False,
#   'contains(right)': False,
#   'contains(seats)': False,
#   'contains(being)': False,
#   'contains(made)': False,
#   'contains(experience)': False,
#   'contains(who)': False,
#   'contains(online)': False,
#   'contains(other)': False,
#   'contains(10)': False,
#   'contains(love)': False,
#   'contains(min)': False,
#   'contains(passengers)': False,
#   'contains(didn)': False,
#   'contains(Please)': False,
#   'contains(her)': False,
#   'contains(30)': False,
#   'contains(sitting)': False,
#   'contains(some)': False,
#   'contains(customers)': False,
#   'contains(staff)': False,
#   'contains(Your)': False,
#   'contains(Our)': False,
#   'contains(book)': False,
#   'contains(she)': False,
#   'contains(worst)': False,
#   'contains(Is)': False,
#   'contains(boarding)': False,
#   'contains(better)': False,
#   'contains(sent)': False,
#   'contains(line)': False,
#   'contains(times)': False,
#   'contains(Not)': False,
#   'contains(said)': False,
#   'contains(booked)': False,
#   'contains(JFK)': False,
#   'contains(long)': False,
#   'contains(won)': False,
#   'contains(Why)': False,
#   'contains(left)': False,
#   'contains(since)': False,
#   'contains(already)': False,
#   'contains(sure)': False,
#   'contains(6)': False,
#   'contains(morning)': False,
#   'contains(yes)': False,
#   'contains(into)': False,
#   'contains(does)': False,
#   'contains(give)': False,
#   'contains(Flightr)': False,
#   'contains(bad)': False,
#   'contains(tonight)': False,
#   'contains(best)': False,
#   'contains(doesn)': True,
#   'contains(miss)': False,
#   'contains(find)': False,
#   'contains(reservation)': False,
#   'contains(d)': False,
#   'contains(where)': False,
#   'contains(fleet)': False,
#   'contains(miles)': False,
#   'contains(fleek)': False,
#   'contains(use)': False,
#   'contains(Booking)': False,
#   'contains(think)': False,
#   'contains(issue)': False,
#   'contains(connection)': False,
#   'contains(night)': False,
#   'contains(Problems)': False,
#   'contains(stuck)': False,
#   'contains(agents)': False,
#   'contains(says)': False,
#   'contains(US)': False,
#   'contains(That)': False,
#   'contains(website)': False,
#   'contains(yet)': False,
#   'contains(refund)': False,
#   'contains(same)': False,
#   'contains(They)': False,
#   'contains(care)': False,
#   'contains(But)': False,
#   'contains(info)': False,
#   'contains(system)': False,
#   'contains(DFW)': False,
#   'contains(hotel)': False,
#   'contains(put)': False,
#   'contains(delays)': False,
#   'contains(A)': False,
#   'contains(Now)': False,
#   'contains(nothing)': False,
#   'contains(ago)': False,
#   'contains(he)': False,
#   'contains(down)': False,
#   'contains(well)': False,
#   'contains(LAX)': False,
#   'contains(tell)': False,
#   'contains(rebooked)': False,
#   'contains(mins)': False,
#   'contains(And)': False,
#   'contains(free)': False,
#   'contains(pay)': False,
#   'contains(tried)': False,
#   'contains(tickets)': False,
#   'contains(issues)': False,
#   'contains(8)': False,
#   'contains(called)': False,
#   'contains(anything)': False,
#   'contains(rebook)': False,
#   'contains(rude)': False,
#   'contains(20)': False,
#   'contains(week)': False,
#   'contains(So)': False,
#   'contains(done)': False,
#   'contains(able)': False,
#   'contains(hope)': False,
#   'contains(until)': False,
#   'contains(If)': False,
#   'contains(class)': False,
#   'contains(checked)': False,
#   'contains(working)': False,
#   'contains(Any)': False,
#   'contains(follow)': False,
#   'contains(keep)': False,
#   'contains(credit)': False,
#   'contains(missed)': False,
#   'contains(7)': False,
#   'contains(say)': False,
#   'contains(its)': False,
#   'contains(ORD)': False,
#   'contains(available)': False,
#   'contains(board)': False,
#   'contains(SFO)': False,
#   'contains(via)': False,
#   'contains(business)': False,
#   'contains(person)': False,
#   'contains(airlines)': False,
#   'contains(flt)': False,
#   'contains(having)': False,
#   'contains(nice)': False,
#   'contains(15)': False,
#   'contains(anyone)': True,
#   'contains(PHL)': False,
#   'contains(usairways)': False,
#   'contains(voucher)': False,
#   'contains(problem)': False,
#   'contains(status)': False,
#   'contains(leave)': False,
#   'contains(helpful)': False,
#   'contains(yesterday)': False,
#   'contains(which)': False,
#   'contains(missing)': False,
#   'contains(gt)': False,
#   'contains(team)': False,
#   'contains(without)': False,
#   'contains(app)': False,
#   'contains(DCA)': False,
#   'contains(answer)': False,
#   'contains(Help)': True,
#   'contains(understand)': False,
#   'contains(Will)': False,
#   'contains(1st)': False,
#   'contains(update)': False,
#   'contains(making)': False,
#   'contains(air)': False,
#   'contains(extra)': False,
#   'contains(speak)': False,
#   'contains(finally)': False,
#   'contains(upgrade)': False,
#   'contains(appreciate)': False,
#   'contains(awesome)': False,
#   'contains(many)': False,
#   'contains(planes)': False,
#   'contains(money)': False,
#   'contains(look)': False,
#   'contains(name)': False,
#   'contains(every)': False,
#   'contains(RT)': False,
#   'contains(come)': False,
#   'contains(claim)': False,
#   'contains(early)': False,
#   'contains(open)': False,
#   'contains(though)': False,
#   'contains(wifi)': False,
#   'contains(rep)': False,
#   'contains(year)': False,
#   'contains(send)': False,
#   'contains(always)': False,
#   'contains(jetblue)': False,
#   'contains(isn)': False,
#   'contains(haven)': False,
#   'contains(earlier)': False,
#   'contains(contact)': False,
#   'contains(also)': False,
#   'contains(departure)': False,
#   'contains(fix)': False,
#   'contains(Do)': False,
#   'contains(connecting)': False,
#   'contains(instead)': False,
#   'contains(different)': False,
#   'contains(attendant)': False,
#   'contains(disappointed)': False,
#   'contains(while)': False,
#   'contains(45)': False,
#   'contains(try)': False,
#   'contains(pass)': False,
#   'contains(something)': False,
#   'contains(site)': False,
#   'contains(Delta)': False,
#   'contains(talk)': False,
#   'contains(On)': False,
#   'contains(employees)': False,
#   'contains(job)': False,
#   'contains(ground)': False,
#   'contains(Dallas)': False,
#   'contains(hung)': False,
#   'contains(wasn)': False,
#   'contains(CLT)': False,
#   'contains(least)': False,
#   'contains(24)': False,
#   'contains(full)': False,
#   'contains(Still)': False,
#   'contains(company)': False,
#   'contains(EWR)': False,
#   'contains(paid)': False,
#   'contains(couldn)': False,
#   'contains(supposed)': False,
#   'contains(took)': False,
#   'contains(actually)': False,
#   'contains(ok)': False,
#   'contains(pilot)': False,
#   'contains(received)': False,
#   'contains(Boston)': False,
#   'contains(old)': False,
#   'contains(amazing)': False,
#   'contains(family)': False,
#   'contains(9)': False,
#   'contains(When)': False,
#   'contains(BOS)': False,
#   'contains(almost)': False,
#   'contains(Chicago)': False,
#   'contains(Denver)': False,
#   'contains(direct)': False,
#   'contains(wife)': False,
#   'contains(looking)': False,
#   'contains(add)': False,
#   'contains(show)': False,
#   'contains(doing)': False,
#   'contains(U)': False,
#   'contains(50)': False,
#   'contains(chance)': False,
#   'contains(food)': False,
#   'contains(happy)': False,
#   'contains(11)': False,
#   'contains(Need)': False,
#   'contains(his)': False,
#   'contains(fail)': False,
#   'contains(DestinationDragons)': False,
#   'contains(40)': False,
#   'contains(far)': False,
#   'contains(card)': False,
#   'contains(weeks)': False,
#   'contains(sorry)': False,
#   'contains(start)': False,
#   'contains(needs)': False,
#   'contains(stranded)': False,
#   'contains(calling)': False,
#   'contains(tweet)': False,
#   'contains(away)': False,
#   'contains(snow)': False,
#   'contains(policy)': False,
#   'contains(those)': False,
#   'contains(ridiculous)': False,
#   'contains(stop)': False,
#   'contains(taking)': False,
#   'contains(wrong)': False,
#   'contains(terrible)': False,
#   'contains(landed)': False,
#   'contains(Vegas)': False,
#   'contains(Have)': False,
#   'contains(vacation)': False,
#   'contains(She)': False,
#   'contains(poor)': False,
#   'contains(reason)': False,
#   'contains(leaving)': False,
#   'contains(enough)': False,
#   'contains(point)': False,
#   'contains(Yes)': False,
#   'contains(Been)': False,
#   'contains(message)': False,
#   'contains(half)': False,
#   'contains(fee)': False,
#   'contains(reply)': False,
#   'contains(account)': False,
#   'contains(25)': False,
#   'contains(sit)': False,
#   'contains(option)': False,
#   'contains(thing)': False,
#   'contains(return)': False,
#   'contains(Great)': False,
#   'contains(horrible)': False,
#   'contains(found)': False,
#   'contains(coming)': False,
#   'contains(gave)': False,
#   'contains(NYC)': False,
#   'contains(most)': False,
#   'contains(American)': False,
#   'contains(charge)': False,
#   'contains(hr)': False,
#   'contains(frustrated)': False,
#   'contains(desk)': False,
#   'contains(car)': False,
#   'contains(little)': False,
#   'contains(together)': False,
#   'contains(everyone)': False,
#   'contains(mechanical)': False,
#   'contains(Really)': False,
#   'contains(went)': False,
#   'contains(past)': False,
#   'contains(broken)': False,
#   'contains(both)': False,
#   'contains(soon)': False,
#   'contains(kids)': False,
#   'contains(around)': False,
#   'contains(link)': False,
#   'contains(bc)': False,
#   'contains(ur)': False,
#   'contains(possible)': False,
#   'contains(confirmation)': False,
#   'contains(question)': False,
#   'contains(using)': False,
#   'contains(him)': False,
#   'contains(destination)': False,
#   'contains(changed)': False,
#   'contains(might)': False,
#   'contains(San)': False,
#   'contains(Southwest)': False,
#   'contains(800)': False,
#   'contains(reservations)': False,
#   'contains(Are)': False,
#   'contains(saying)': False,
#   'contains(less)': False,
#   'contains(IAD)': False,
#   'contains(few)': False,
#   'contains(Newark)': False,
#   'contains(Was)': False,
#   'contains(200)': False,
#   'contains(longer)': False,
#   'contains(lot)': False,
#   'contains(offer)': False,
#   'contains(else)': False,
#   'contains(All)': False,
#   'contains(landing)': False,
#   'contains(runway)': False,
#   'contains(worse)': False,
#   'contains(Airways)': False,
#   'contains(Thx)': False,
#   'contains(things)': False,
#   'contains(New)': True,
#   'contains(Hi)': False,
#   'contains(idea)': False,
#   'contains(given)': False,
#   'contains(Twitter)': False,
#   'contains(these)': False,
#   'contains(stay)': False,
#   'contains(once)': False,
#   'contains(cost)': False,
#   'contains(unacceptable)': False,
#   'contains(Charlotte)': False,
#   'contains(friend)': False,
#   'contains(Houston)': False,
#   'contains(thru)': False,
#   'contains(telling)': False,
#   'contains(during)': False,
#   'contains(UA)': False,
#   'contains(There)': False,
#   'contains(hear)': False,
#   'contains(lack)': False,
#   'contains(hard)': False,
#   'contains(scheduled)': False,
#   'contains(three)': False,
#   'contains(happened)': False,
#   'contains(12)': False,
#   'contains(twice)': False,
#   'contains(used)': False,
#   'contains(mean)': False,
#   'contains(https)': False,
#   'contains(asked)': False,
#   'contains(FLL)': False,
#   'contains(minute)': False,
#   'contains(LGA)': False,
#   'contains(attendants)': False,
#   'contains(problems)': False,
#   'contains(points)': False,
#   'contains(real)': False,
#   'contains(100)': False,
#   'contains(calls)': False,
#   'contains(Never)': False,
#   'contains(believe)': False,
#   'contains(life)': False,
#   'contains(own)': False,
#   'contains(information)': False,
#   'contains(assistance)': False,
#   'contains(Don)': False,
#   'contains(cool)': False,
#   'contains(big)': False,
#   'contains(options)': False,
#   'contains(sucks)': False,
#   'contains(row)': False,
#   'contains(PHX)': False,
#   'contains(Very)': False,
#   'contains(carry)': False,
#   'contains(member)': False,
#   'contains(traveling)': False,
#   'contains(may)': False,
#   'contains(end)': False,
#   'contains(arrive)': False,
#   'contains(waited)': False,
#   'contains(NOT)': False,
#   'contains(heard)': False,
#   'contains(maintenance)': False,
#   'contains(Customer)': False,
#   'contains(changes)': False,
#   'contains(Good)': False,
#   'contains(such)': False,
#   'contains(error)': False,
#   'contains(reFlight)': False,
#   'contains(guess)': False,
#   'contains(terminal)': False,
#   'contains(arrived)': False,
#   'contains(seriously)': False,
#   'contains(wouldn)': False,
#   'contains(quick)': False,
#   'contains(counting)': False,
#   'contains(YOU)': False,
#   'contains(expect)': False,
#   'contains(busy)': False,
#   'contains(frustrating)': False,
#   'contains(forward)': False,
#   'contains(In)': False,
#   'contains(pick)': False,
#   'contains(BWI)': False,
#   'contains(Monday)': False,
#   'contains(process)': False,
#   'contains(request)': False,
#   'contains(IAH)': False,
#   'contains(standby)': False,
#   'contains(Airlines)': False,
#   'contains(CEO)': False,
#   'contains(Love)': False,
#   'contains(b)': False,
#   'contains(feel)': False,
#   'contains(room)': False,
#   'contains(SWA)': False,
#   'contains(aren)': False,
#   'contains(loyal)': False,
#   'contains(2nd)': False,
#   'contains(reach)': False,
#   'contains(ask)': False,
#   'contains(oh)': False,
#   'contains(needed)': False,
#   'contains(everything)': False,
#   'contains(joke)': False,
#   'contains(fees)': False,
#   'contains(apology)': False,
#   'contains(complaint)': False,
#   'contains(thx)': False,
#   'contains(computer)': False,
#   'contains(years)': False,
#   'contains(tarmac)': False,
#   'contains(Miami)': False,
#   'contains(cannot)': False,
#   'contains(second)': False,
#   'contains(non)': False,
#   'contains(checking)': False,
#   'contains(cust)': False,
#   'contains(communication)': False,
#   'contains(Would)': False,
#   'contains(DEN)': False,
#   'contains(THE)': False,
#   'contains(DC)': False,
#   'contains(international)': False,
#   'contains(wanted)': False,
#   'contains(each)': False,
#   'contains(address)': False,
#   'contains(y)': False,
#   'contains(looks)': False,
#   'contains(boarded)': False,
#   'contains(pilots)': False,
#   'contains(southwestair)': False,
#   'contains(asking)': False,
#   'contains(Air)': False,
#   'contains(passenger)': False,
#   'contains(plus)': False,
#   'contains(Imaginedragons)': False,
#   'contains(awful)': False,
#   'contains(guy)': False,
#   'contains(makes)': False,
#   'contains(paying)': False,
#   'contains(NO)': False,
#   'contains(After)': False,
#   'contains(deal)': False,
#   'contains(empty)': False,
#   'contains(SW)': False,
#   'contains(form)': False,
#   'contains(taken)': False,
#   'contains(place)': False,
#   'contains(run)': False,
#   'contains(between)': False,
#   'contains(Flighting)': False,
#   'contains(thought)': False,
#   'contains(Also)': False,
#   'contains(leg)': False,
#   'contains(happens)': False,
#   'contains(Trying)': False,
#   'contains(under)': False,
#   'contains(bring)': False,
#   'contains(updates)': False,
#   'contains(provide)': False,
#   'contains(lose)': False,
#   'contains(whole)': False,
#   'contains(Sunday)': False,
#   'contains(seem)': True,
#   'contains(world)': False,
#   'contains(sleep)': False,
#   'contains(month)': False,
#   'contains(entire)': False,
#   'contains(happen)': False,
#   'contains(seems)': False,
#   'contains(helping)': False,
#   'contains(Philly)': False,
#   'contains(MCO)': False,
#   'contains(counter)': False,
#   'contains(respond)': False,
#   'contains(spent)': False,
#   'contains(Gate)': False,
#   'contains(case)': False,
#   'contains(fault)': False,
#   'contains(Flightlations)': False,
#   'contains(months)': False,
#   'contains(AM)': False,
#   'contains(award)': False,
#   'contains(buy)': False,
#   'contains(LA)': False,
#   'contains(suck)': False,
#   'contains(purchase)': False,
#   'contains(Worst)': False,
#   'contains(flew)': False,
#   'contains(drive)': False,
#   'contains(correct)': False,
#   'contains(human)': False,
#   'contains(HELP)': False,
#   'contains(beyond)': False,
#   'contains(upset)': False,
#   'contains(price)': False,
#   'contains(lt)': False,
#   'contains(moved)': False,
#   'contains(details)': False,
#   'contains(Maybe)': False,
#   'contains(pretty)': False,
#   'contains(list)': False,
#   'contains(holding)': False,
#   'contains(either)': False,
#   'contains(Nashville)': False,
#   'contains(group)': False,
#   'contains(automated)': False,
#   'contains(cant)': False,
#   'contains(situation)': False,
#   'contains(maybe)': False,
#   'contains(Got)': True,
#   'contains(Airport)': False,
#   'contains(sat)': False,
#   'contains(date)': False,
#   'contains(Austin)': False,
#   'contains(appreciated)': False,
#   'contains(At)': False,
#   'contains(live)': False,
#   'contains(rather)': False,
#   'contains(Had)': False,
#   'contains(hoping)': False,
#   'contains(Only)': False,
#   'contains(2015)': False,
#   'contains(First)': False,
#   'contains(offered)': False,
#   'contains(supervisor)': False,
#   'contains(bought)': False,
#   'contains(record)': False,
#   'contains(He)': False,
#   'contains(figure)': False,
#   'contains(compensation)': False,
#   'contains(flown)': False,
#   'contains(following)': False,
#   'contains(confirmed)': False,
#   'contains(TSA)': False,
#   'contains(hi)': False,
#   'contains(americanair)': False,
#   'contains(switch)': False,
#   'contains(Delayed)': False,
#   'contains(city)': False,
#   'contains(disconnected)': False,
#   'contains(reschedule)': False,
#   'contains(Tarmac)': False,
#   'contains(Another)': False,
#   'contains(future)': False,
#   'contains(fine)': False,
#   'contains(treat)': False,
#   'contains(connections)': False,
#   'contains(employee)': False,
#   'contains(Get)': False,
#   'contains(clothes)': False,
#   'contains(plans)': False,
#   'contains(UnitedAirlines)': False,
#   'contains(handle)': False,
#   'contains(charged)': False,
#   'contains(c)': False,
#   'contains(members)': False,
#   'contains(original)': False,
#   'contains(customerservice)': False,
#   'contains(allow)': False,
#   'contains(luck)': False,
#   'contains(delivered)': False,
#   'contains(ready)': False,
#   'contains(gets)': False,
#   'contains(Orlando)': False,
#   'contains(kind)': False,
#   'contains(high)': False,
#   'contains(companion)': False,
#   'contains(checkin)': False,
#   'contains(easy)': False,
#   'contains(friends)': False,
#   'contains(hey)': False,
#   'contains(support)': False,
#   'contains(Hey)': False,
#   'contains(allowed)': False,
#   'contains(o)': False,
#   'contains(means)': False,
#   'contains(part)': False,
#   'contains(lol)': False,
#   'contains(set)': False,
#   'contains(helped)': False,
#   'contains(USAir)': False,
#   'contains(fact)': False,
#   'contains(wish)': False,
#   'contains(Flightlation)': False,
#   'contains(currently)': False,
#   'contains(One)': False,
#   'contains(seen)': False,
#   'contains(fare)': False,
#   'contains(schedule)': False,
#   'contains(top)': False,
#   'contains(cause)': False,
#   'contains(front)': False,
#   'contains(pls)': False,
#   'contains(hate)': False,
#   'contains(Tuesday)': False,
#   'contains(myself)': False,
#   'contains(ice)': False,
#   'contains(Well)': False,
#   'contains(C)': False,
#   'contains(running)': False,
#   'contains(share)': False,
#   'contains(storm)': False,
#   'contains(Looking)': False,
#   'contains(middle)': False,
#   'contains(aircraft)': False,
#   'contains(giving)': False,
#   'contains(glad)': False,
#   'contains(gives)': False,
#   'contains(shouldn)': False,
#   'contains(southwest)': False,
#   'contains(As)': False,
#   'contains(ppl)': False,
#   'contains(losing)': False,
#   'contains(Oh)': False,
#   'contains(ATL)': False,
#   'contains(cabin)': False,
#   'contains(weekend)': False,
#   'contains(word)': False,
#   'contains(reps)': False,
#   'contains(LAS)': False,
#   'contains(fun)': False,
#   'contains(Service)': False,
#   'contains(several)': False,
#   'contains(Feb)': False,
#   'contains(Atlanta)': False,
#   'contains(cold)': False,
#   'contains(water)': False,
#   'contains(pm)': False,
#   'contains(Should)': False,
#   'contains(answering)': False,
#   'contains(Then)': False,
#   'contains(sense)': False,
#   'contains(safety)': False,
#   'contains(round)': False,
#   'contains(changing)': False,
#   'contains(space)': False,
#   'contains(came)': False,
#   'contains(Did)': False,
#   'contains(gonna)': False,
#   'contains(TO)': False,
#   'contains(rescheduled)': False,
#   'contains(multiple)': False,
#   'contains(answers)': False,
#   'contains(probably)': False,
#   'contains(Flights)': False,
#   'contains(explain)': False,
#   'contains(shit)': False,
#   'contains(dont)': False,
#   'contains(land)': False,
#   'contains(000)': False,
#   'contains(fixed)': False,
#   'contains(okay)': False,
#   'contains(load)': False,
#   'contains(country)': False,
#   'contains(access)': False,
#   'contains(overnight)': False,
#   'contains(Pls)': False,
#   'contains(BNA)': False,
#   'contains(takes)': False,
#   'contains(Who)': False,
#   'contains(super)': False,
#   'contains(layover)': False,
#   'contains(goes)': False,
#   'contains(plan)': False,
#   'contains(birthday)': False,
#   'contains(mine)': False,
#   'contains(afternoon)': False,
#   'contains(jet)': False,
#   'contains(crazy)': False,
#   'contains(arrival)': False,
#   'contains(sending)': False,
#   'contains(sad)': False,
#   'contains(child)': False,
#   'contains(route)': False,
#   'contains(RDU)': False,
#   'contains(knew)': False,
#   'contains(control)': False,
#   'contains(attitude)': False,
#   'contains(tix)': False,
#   'contains(inconvenience)': False,
#   'contains(Unacceptable)': False,
#   'contains(Let)': False,
#   'contains(overhead)': False,
#   'contains(90)': False,
#   'contains(Terrible)': False,
#   'contains(complete)': False,
#   'contains(yeah)': False,
#   'contains(Friday)': False,
#   'contains(23)': False,
#   'contains(r)': False,
#   'contains(wow)': False,
#   'contains(showing)': False,
#   'contains(works)': False,
#   'contains(3rd)': False,
#   'contains(responding)': False,
#   'contains(ASAP)': False,
#   'contains(keeps)': False,
#   'contains(media)': False,
#   'contains(services)': False,
#   'contains(husband)': False,
#   'contains(confirm)': False,
#   'contains(letter)': False,
#   'contains(phones)': False,
#   'contains(completely)': False,
#   'contains(mom)': False,
#   'contains(relations)': False,
#   'contains(Wall)': False,
#   'contains(Flt)': False,
#   'contains(treated)': False,
#   'contains(22)': False,
#   'contains(drop)': False,
#   'contains(TV)': False,
#   'contains(report)': False,
#   'contains(hasn)': False,
#   'contains(MY)': False,
#   'contains(yr)': False,
#   'contains(dm)': False,
#   'contains(PLEASE)': False,
#   'contains(dealing)': False,
#   'contains(true)': False,
#   'contains(page)': False,
#   'contains(despite)': False,
#   'contains(course)': False,
#   'contains(evening)': False,
#   'contains(code)': False,
#   'contains(pre)': False,
#   'contains(Or)': False,
#   'contains(Where)': False,
#   'contains(matter)': False,
#   'contains(closed)': False,
#   'contains(read)': False,
#   'contains(area)': False,
#   'contains(yall)': False,
#   'contains(bit)': False,
#   'contains(flyer)': False,
#   ...},
#  'negative')

# %%
#checking the length of the list of features
len(featuresets)
# Out:
# 14640

# %%
#We are ready now to do machine learning using the unigram list we just created
#we use a Naive Bayes classifier with 5-fold cross validation for training on sentiments using unigrams

import numpy as np
from sklearn.model_selection import KFold

kf = KFold(n_splits = 5)
sum = 0

for train, test in kf.split(featuresets):
    train_data = np.array(featuresets)[train]
    test_data = np.array(featuresets)[test]
    classifier = nltk.NaiveBayesClassifier.train(train_data)
    sum += nltk.classify.accuracy(classifier, test_data)

#storing the score in a variable 
acc1 = sum/5

# %%
#let's see the accuracy score for this unigram classifier

acc1
# Out:
# 0.769535519125683

# %%
# We will now create a new feature: bigrams
#we'll use the code we already know from class labs 

from nltk.collocations import *
import re

#data cleaning and preprocessing
stopwords = nltk.corpus.stopwords.words('english')

def alpha(w):
    pattern = re.compile('^[^a-z]+$')
    if(pattern.match(w)):
        return True
    else:
        return False

#creating bigrams features for the corpus and applying cleaning steps
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(all_words)
finder.apply_word_filter(alpha)
finder.apply_word_filter(lambda w: w in stopwords)
scored = finder.score_ngrams(bigram_measures.raw_freq)
scored[:10]
# Out:
# [(('customer', 'service'), 0.0019616017390139137),
#  (('Cancelled', 'Flightled'), 0.0018871576502467822),
#  (('Late', 'Flight'), 0.0009268289051507866),
#  (('Cancelled', 'Flighted'), 0.0008374959986302288),
#  (('Late', 'Flightr'), 0.0005769416879452687),
#  (('JetBlue', 'Our'), 0.0005434418480000596),
#  (('Booking', 'Problems'), 0.000539719643561703),
#  (('Cancelled', 'Flight'), 0.000539719643561703),
#  (('Our', 'fleet'), 0.000539719643561703),
#  (('fleek', 'http'), 0.0005322752346849899)]

# %%
#extracting clean bigrams (no frequency information)
bigram_features = [bigram for (bigram, count) in scored[:2000]]
#printing the first 30 for confirmation
bigram_features[:30]
# Out:
# [('customer', 'service'),
#  ('Cancelled', 'Flightled'),
#  ('Late', 'Flight'),
#  ('Cancelled', 'Flighted'),
#  ('Late', 'Flightr'),
#  ('JetBlue', 'Our'),
#  ('Booking', 'Problems'),
#  ('Cancelled', 'Flight'),
#  ('Our', 'fleet'),
#  ('fleek', 'http'),
#  ('USAirways', 'AmericanAir'),
#  ('Flight', 'Booking'),
#  ('call', 'back'),
#  ('united', 'thanks'),
#  ('JetBlue', 'thanks'),
#  ('gate', 'agent'),
#  ('AmericanAir', 'thanks'),
#  ('connecting', 'flight'),
#  ('help', 'united'),
#  ('get', 'home'),
#  ('flight', 'Cancelled'),
#  ('last', 'night'),
#  ('hours', 'Late'),
#  ('USAirways', 'thanks'),
#  ('hour', 'delay'),
#  ('first', 'class'),
#  ('flight', 'attendant'),
#  ('reFlight', 'Booking'),
#  ('united', 'yes'),
#  ('Flightled', 'flight')]

# %%
#after finding all bigrams of the corpus (i.e. the bigram feature of the corpus)
#we create a function that checks if those feature bigrams are present on each specific document
#exactly as we did with unigrams

def bi_document_features(document, bigram_features):
    document_words = list(nltk.bigrams(document))
    features = {}
    for word in bigram_features:
        #boolean logic will retunt 'True' if there is a match, or 'False' if not
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %%
#applying the function to our documents
featuresets2 = [(bi_document_features(d, bigram_features), c) for (d, c) in docs]

#seeing the featureset for the first document
featuresets2[0]
# Out:
# ({"contains(('customer', 'service'))": False,
#   "contains(('Cancelled', 'Flightled'))": False,
#   "contains(('Late', 'Flight'))": False,
#   "contains(('Cancelled', 'Flighted'))": False,
#   "contains(('Late', 'Flightr'))": False,
#   "contains(('JetBlue', 'Our'))": False,
#   "contains(('Booking', 'Problems'))": False,
#   "contains(('Cancelled', 'Flight'))": False,
#   "contains(('Our', 'fleet'))": False,
#   "contains(('fleek', 'http'))": False,
#   "contains(('USAirways', 'AmericanAir'))": False,
#   "contains(('Flight', 'Booking'))": False,
#   "contains(('call', 'back'))": False,
#   "contains(('united', 'thanks'))": False,
#   "contains(('JetBlue', 'thanks'))": False,
#   "contains(('gate', 'agent'))": False,
#   "contains(('AmericanAir', 'thanks'))": False,
#   "contains(('connecting', 'flight'))": False,
#   "contains(('help', 'united'))": False,
#   "contains(('get', 'home'))": False,
#   "contains(('flight', 'Cancelled'))": False,
#   "contains(('last', 'night'))": False,
#   "contains(('hours', 'Late'))": False,
#   "contains(('USAirways', 'thanks'))": False,
#   "contains(('hour', 'delay'))": False,
#   "contains(('first', 'class'))": False,
#   "contains(('flight', 'attendant'))": False,
#   "contains(('reFlight', 'Booking'))": False,
#   "contains(('united', 'yes'))": False,
#   "contains(('Flightled', 'flight'))": False,
#   "contains(('united', 'thank'))": False,
#   "contains(('still', 'waiting'))": False,
#   "contains(('SouthwestAir', 'thanks'))": False,
#   "contains(('another', 'flight'))": False,
#   "contains(('wait', 'time'))": False,
#   "contains(('Cancelled', 'Flighting'))": False,
#   "contains(('You', 'guys'))": False,
#   "contains(('united', 'flight'))": False,
#   "contains(('next', 'flight'))": False,
#   "contains(('Cancelled', 'Flightlations'))": False,
#   "contains(('USAirways', 'flight'))": False,
#   "contains(('united', 'Thanks'))": False,
#   "contains(('flight', 'united'))": False,
#   "contains(('please', 'help'))": False,
#   "contains(('two', 'hours'))": False,
#   "contains(('baggage', 'claim'))": False,
#   "contains(('flight', 'USAirways'))": False,
#   "contains(('flight', 'tomorrow'))": False,
#   "contains(('would', 'like'))": False,
#   "contains(('On', 'hold'))": False,
#   "contains(('flight', 'AmericanAir'))": False,
#   "contains(('boarding', 'pass'))": False,
#   "contains(('delayed', 'flight'))": False,
#   "contains(('flight', 'attendants'))": False,
#   "contains(('tomorrow', 'morning'))": False,
#   "contains(('SouthwestAir', 'Thanks'))": False,
#   "contains(('earlier', 'flight'))": False,
#   "contains(('first', 'time'))": False,
#   "contains(('help', 'USAirways'))": False,
#   "contains(('looks', 'like'))": False,
#   "contains(('service', 'united'))": False,
#   "contains(('Please', 'help'))": False,
#   "contains(('Thanks', 'USAirways'))": False,
#   "contains(('Cancelled', 'Flightlation'))": False,
#   "contains(('Thanks', 'united'))": False,
#   "contains(('flight', 'JetBlue'))": False,
#   "contains(('AmericanAir', 'You'))": False,
#   "contains(('AmericanAir', 'flight'))": False,
#   "contains(('JetBlue', 'flight'))": False,
#   "contains(('JetBlue', 'thank'))": False,
#   "contains(('help', 'AmericanAir'))": False,
#   "contains(('need', 'help'))": False,
#   "contains(('worst', 'airline'))": False,
#   "contains(('1st', 'class'))": False,
#   "contains(('AmericanAir', 'Thanks'))": False,
#   "contains(('let', 'us'))": False,
#   "contains(('AmericanAir', 'USAirways'))": False,
#   "contains(('Thanks', 'AmericanAir'))": False,
#   "contains(('checked', 'bag'))": False,
#   "contains(('never', 'fly'))": False,
#   "contains(('service', 'AmericanAir'))": False,
#   "contains(('worst', 'customer'))": False,
#   "contains(('flight', 'SouthwestAir'))": False,
#   "contains(('AmericanAir', 'Thank'))": False,
#   "contains(('My', 'flight'))": False,
#   "contains(('SouthwestAir', 'thank'))": False,
#   "contains(('Thanks', 'SouthwestAir'))": False,
#   "contains(('USAirways', 'thank'))": False,
#   "contains(('service', 'USAirways'))": False,
#   "contains(('united', 'Thank'))": False,
#   "contains(('SouthwestAir', 'Thank'))": False,
#   "contains(('bad', 'weather'))": False,
#   "contains(('credit', 'card'))": False,
#   "contains(('email', 'address'))": False,
#   "contains(('even', 'though'))": False,
#   "contains(('gate', 'agents'))": False,
#   "contains(('AmericanAir', 'yes'))": False,
#   "contains(('Flighted', 'flight'))": False,
#   "contains(('mechanical', 'issues'))": False,
#   "contains(('would', 'love'))": False,
#   "contains(('JetBlue', 'Thanks'))": False,
#   "contains(('No', 'one'))": False,
#   "contains(('another', 'airline'))": False,
#   "contains(('b', 'c'))": False,
#   "contains(('new', 'flight'))": False,
#   "contains(('thanks', 'united'))": False,
#   "contains(('two', 'days'))": False,
#   "contains(('every', 'time'))": False,
#   "contains(('flight', 'crew'))": False,
#   "contains(('great', 'flight'))": False,
#   "contains(('help', 'SouthwestAir'))": False,
#   "contains(('phone', 'number'))": False,
#   "contains(('united', 'You'))": False,
#   "contains(('AmericanAir', 'Flight'))": False,
#   "contains(('AmericanAir', 'thank'))": False,
#   "contains(('Flightled', 'flights'))": False,
#   "contains(('flight', 'today'))": False,
#   "contains(('get', 'us'))": False,
#   "contains(('make', 'sure'))": False,
#   "contains(('thanks', 'USAirways'))": False,
#   "contains(('united', 'please'))": False,
#   "contains(('Flight', 'Cancelled'))": False,
#   "contains(('SouthwestAir', 'flight'))": False,
#   "contains(('change', 'fee'))": False,
#   "contains(('delayed', 'due'))": False,
#   "contains(('flight', 'delayed'))": False,
#   "contains(('help', 'us'))": False,
#   "contains(('last', 'time'))": False,
#   "contains(('next', 'time'))": False,
#   "contains(('today', 'united'))": False,
#   "contains(('JetBlue', 'Thank'))": False,
#   "contains(('USAirways', 'yes'))": False,
#   "contains(('could', 'get'))": False,
#   "contains(('customer', 'relations'))": False,
#   "contains(('got', 'Cancelled'))": False,
#   "contains(('hour', 'wait'))": False,
#   "contains(('hours', 'ago'))": False,
#   "contains(('last', 'week'))": False,
#   "contains(('round', 'trip'))": False,
#   "contains(('JetBlue', 'yes'))": False,
#   "contains(('Thanks', 'JetBlue'))": False,
#   "contains(('USAirways', 'No'))": False,
#   "contains(('airline', 'ever'))": False,
#   "contains(('flight', 'home'))": False,
#   "contains(('get', 'back'))": False,
#   "contains(('great', 'job'))": False,
#   "contains(('help', 'JetBlue'))": False,
#   "contains(('keep', 'getting'))": False,
#   "contains(('one', 'way'))": False,
#   "contains(('return', 'flight'))": False,
#   "contains(('year', 'old'))": False,
#   "contains(('AmericanAir', 'My'))": False,
#   "contains(('JetBlue', 'Airways'))": False,
#   "contains(('Wall', 'Street'))": False,
#   "contains(('first', 'flight'))": False,
#   "contains(('give', 'us'))": False,
#   "contains(('last', 'flight'))": False,
#   "contains(('poor', 'customer'))": False,
#   "contains(('quick', 'response'))": False,
#   "contains(('thanks', 'SouthwestAir'))": False,
#   "contains(('time', 'SouthwestAir'))": False,
#   "contains(('time', 'USAirways'))": False,
#   "contains(('Cancelled', 'Flights'))": False,
#   "contains(('Looks', 'like'))": False,
#   "contains(('San', 'Diego'))": False,
#   "contains(('SouthwestAir', 'Flight'))": False,
#   "contains(('USAirways', 'please'))": False,
#   "contains(('Your', 'customer'))": False,
#   "contains(('back', 'home'))": False,
#   "contains(('cust', 'service'))": False,
#   "contains(('delayed', 'flights'))": False,
#   "contains(('ground', 'crew'))": False,
#   "contains(('hrs', 'Late'))": False,
#   "contains(('thanks', 'JetBlue'))": False,
#   "contains(('united', 'Flight'))": False,
#   "contains(('united', 'It'))": False,
#   "contains(('weeks', 'ago'))": False,
#   "contains(('AmericanAir', 'No'))": False,
#   "contains(('At', 'least'))": False,
#   "contains(('Cancelled', 'Flightling'))": False,
#   "contains(('Flight', 'flight'))": False,
#   "contains(('SouthwestAir', 'please'))": False,
#   "contains(('USAirways', 'Thank'))": False,
#   "contains(('USAirways', 'Thanks'))": False,
#   "contains(('departure', 'time'))": False,
#   "contains(('direct', 'flight'))": False,
#   "contains(('hour', 'flight'))": False,
#   "contains(('never', 'got'))": False,
#   "contains(('reLate', 'Flightd'))": False,
#   "contains(('service', 'JetBlue'))": False,
#   "contains(('still', 'sitting'))": False,
#   "contains(('time', 'united'))": False,
#   "contains(('today', 'AmericanAir'))": False,
#   "contains(('united', 'Why'))": False,
#   "contains(('AmericanAir', 'Can'))": False,
#   "contains(('AmericanAir', 'please'))": False,
#   "contains(('Customer', 'service'))": False,
#   "contains(('My', 'wife'))": False,
#   "contains(('SouthwestAir', 'My'))": False,
#   "contains(('USAirways', 'My'))": False,
#   "contains(('What', 'gives'))": False,
#   "contains(('call', 'center'))": False,
#   "contains(('confirmation', 'number'))": False,
#   "contains(('customer', 'care'))": False,
#   "contains(('experience', 'ever'))": False,
#   "contains(('lost', 'bag'))": False,
#   "contains(('minutes', 'ago'))": False,
#   "contains(('social', 'media'))": False,
#   "contains(('thanks', 'AmericanAir'))": False,
#   "contains(('time', 'AmericanAir'))": False,
#   "contains(('united', 'Hi'))": False,
#   "contains(('united', 'Yes'))": False,
#   "contains(('wait', 'times'))": False,
#   "contains(('Any', 'way'))": False,
#   "contains(('Customer', 'Service'))": False,
#   "contains(('Looking', 'forward'))": False,
#   "contains(('USAirways', 'Can'))": False,
#   "contains(('appease', 'passengers'))": False,
#   "contains(('back', 'Late'))": False,
#   "contains(('call', 'volume'))": False,
#   "contains(('companion', 'pass'))": False,
#   "contains(('dividend', 'miles'))": False,
#   "contains(('good', 'work'))": False,
#   "contains(('home', 'USAirways'))": False,
#   "contains(('hour', 'Late'))": False,
#   "contains(('next', 'day'))": False,
#   "contains(('service', 'ever'))": False,
#   "contains(('service', 'line'))": False,
#   "contains(('service', 'rep'))": False,
#   "contains(('time', 'flying'))": False,
#   "contains(('tomorrow', 'united'))": False,
#   "contains(('united', 'How'))": False,
#   "contains(('American', 'Airlines'))": False,
#   "contains(('Jet', 'Blue'))": False,
#   "contains(('JetBlue', 'Flight'))": False,
#   "contains(('SouthwestAir', 'Just'))": False,
#   "contains(('USAirways', 'How'))": False,
#   "contains(('USAirways', 'You'))": False,
#   "contains(('United', 'flight'))": False,
#   "contains(('direct', 'flights'))": False,
#   "contains(('feel', 'like'))": False,
#   "contains(('flights', 'AmericanAir'))": False,
#   "contains(('go', 'home'))": False,
#   "contains(('months', 'ago'))": False,
#   "contains(('please', 'AmericanAir'))": False,
#   "contains(('service', 'SouthwestAir'))": False,
#   "contains(('service', 'desk'))": False,
#   "contains(('time', 'JetBlue'))": False,
#   "contains(('told', 'us'))": False,
#   "contains(('tomorrow', 'AmericanAir'))": False,
#   "contains(('united', 'What'))": False,
#   "contains(('united', 'well'))": False,
#   "contains(('weather', 'reLate'))": False,
#   "contains(('2nd', 'time'))": False,
#   "contains(('Any', 'chance'))": False,
#   "contains(('SouthwestAir', 'Hi'))": False,
#   "contains(('SouthwestAir', 'How'))": False,
#   "contains(('USAirways', 'Flight'))": False,
#   "contains(('USAirways', 'still'))": False,
#   "contains(('United', 'Airlines'))": False,
#   "contains(('boarding', 'passes'))": False,
#   "contains(('day', 'USAirways'))": False,
#   "contains(('flight', 'back'))": False,
#   "contains(('get', 'thru'))": False,
#   "contains(('great', 'customer'))": False,
#   "contains(('hours', 'USAirways'))": False,
#   "contains(('hours', 'united'))": False,
#   "contains(('non', 'stop'))": False,
#   "contains(('phone', 'system'))": False,
#   "contains(('several', 'times'))": False,
#   "contains(('tomorrow', 'USAirways'))": False,
#   "contains(('travel', 'advisory'))": False,
#   "contains(('united', 'My'))": False,
#   "contains(('united', 'No'))": False,
#   "contains(('united', 'The'))": False,
#   "contains(('united', 'airlines'))": False,
#   "contains(('united', 'united'))": False,
#   "contains(('worst', 'experience'))": False,
#   "contains(('AmericanAir', 'It'))": False,
#   "contains(('AmericanAir', 'The'))": False,
#   "contains(('Any', 'help'))": False,
#   "contains(('Can', 'someone'))": False,
#   "contains(('Cancelled', 'Flightation'))": False,
#   "contains(('Help', 'AmericanAir'))": False,
#   "contains(('How', 'long'))": False,
#   "contains(('JetBlue', 'You'))": False,
#   "contains(('Las', 'Vegas'))": False,
#   "contains(('San', 'Juan'))": False,
#   "contains(('SouthwestAir', 'Yes'))": False,
#   "contains(('SouthwestAir', 'yes'))": False,
#   "contains(('USAirways', 'Your'))": False,
#   "contains(('back', 'SouthwestAir'))": False,
#   "contains(('finally', 'got'))": False,
#   "contains(('flight', 'without'))": False,
#   "contains(('flight', 'yesterday'))": False,
#   "contains(('go', 'back'))": False,
#   "contains(('international', 'flight'))": False,
#   "contains(('looking', 'forward'))": False,
#   "contains(('missed', 'connection'))": False,
#   "contains(('please', 'USAirways'))": False,
#   "contains(('service', 'today'))": False,
#   "contains(('three', 'hours'))": False,
#   "contains(('united', 'Just'))": False,
#   "contains(('united', 'Your'))": False,
#   "contains(('united', 'still'))": False,
#   "contains(('us', 'know'))": False,
#   "contains(('AmericanAir', 'Cancelled'))": False,
#   "contains(('AmericanAir', 'Hi'))": False,
#   "contains(('AmericanAir', 'How'))": False,
#   "contains(('AmericanAir', 'Your'))": False,
#   "contains(('AmericanAir', 'united'))": False,
#   "contains(('Any', 'idea'))": False,
#   "contains(('Cancelled', 'Flightations'))": False,
#   "contains(('Fingers', 'crossed'))": False,
#   "contains(('Flightled', 'united'))": False,
#   "contains(('Good', 'luck'))": False,
#   "contains(('Help', 'JetBlue'))": False,
#   "contains(('Help', 'united'))": False,
#   "contains(('JetBlue', 'That'))": False,
#   "contains(('JetBlue', 'well'))": False,
#   "contains(('Just', 'got'))": False,
#   "contains(('Need', 'help'))": False,
#   "contains(('New', 'York'))": False,
#   "contains(('Not', 'happy'))": False,
#   "contains(('SouthwestAir', 'Can'))": False,
#   "contains(('SouthwestAir', 'FortuneMagazine'))": False,
#   "contains(('USAirways', 'It'))": False,
#   "contains(('another', 'hour'))": False,
#   "contains(('bag', 'united'))": False,
#   "contains(('best', 'airline'))": False,
#   "contains(('car', 'seat'))": False,
#   "contains(('done', 'united'))": False,
#   "contains(('flight', 'delay'))": False,
#   "contains(('flight', 'got'))": False,
#   "contains(('flight', 'time'))": True,
#   "contains(('flight', 'w'))": False,
#   "contains(('flights', 'today'))": False,
#   "contains(('get', 'anyone'))": False,
#   "contains(('half', 'hour'))": False,
#   "contains(('hold', 'times'))": False,
#   "contains(('jet', 'blue'))": False,
#   "contains(('last', 'minute'))": False,
#   "contains(('last', 'name'))": False,
#   "contains(('last', 'year'))": False,
#   "contains(('long', 'time'))": False,
#   "contains(('long', 'wait'))": False,
#   "contains(('loyal', 'customers'))": False,
#   "contains(('lt', 'lt'))": False,
#   "contains(('min', 'Late'))": False,
#   "contains(('never', 'flying'))": False,
#   "contains(('online', 'united'))": False,
#   "contains(('original', 'flight'))": False,
#   "contains(('phone', 'AmericanAir'))": False,
#   "contains(('please', 'fix'))": False,
#   "contains(('service', 'agents'))": False,
#   "contains(('someone', 'else'))": False,
#   "contains(('united', 'Can'))": False,
#   "contains(('via', 'Twitter'))": False,
#   "contains(('weather', 'united'))": False,
#   "contains(('work', 'JetBlue'))": False,
#   "contains(('AmericanAir', 'We'))": False,
#   "contains(('AmericanAir', 'Yes'))": False,
#   "contains(('Great', 'job'))": False,
#   "contains(('JetBlue', 'What'))": False,
#   "contains(('Journal', 'http'))": False,
#   "contains(('Just', 'sent'))": False,
#   "contains(('No', 'help'))": False,
#   "contains(('SouthwestAir', 'Is'))": False,
#   "contains(('That', 'would'))": False,
#   "contains(('The', 'flight'))": False,
#   "contains(('USAirways', 'And'))": False,
#   "contains(('USAirways', 'Cancelled'))": False,
#   "contains(('USAirways', 'What'))": False,
#   "contains(('USAirways', 'worst'))": False,
#   "contains(('Worst', 'airline'))": False,
#   "contains(('airline', 'USAirways'))": False,
#   "contains(('airline', 'united'))": False,
#   "contains(('award', 'travel'))": False,
#   "contains(('back', 'AmericanAir'))": False,
#   "contains(('baggage', 'fees'))": False,
#   "contains(('business', 'class'))": False,
#   "contains(('cant', 'get'))": False,
#   "contains(('cross', 'country'))": False,
#   "contains(('day', 'united'))": False,
#   "contains(('delayed', 'united'))": False,
#   "contains(('disappointed', 'united'))": False,
#   "contains(('even', 'get'))": False,
#   "contains(('flight', 'amp'))": False,
#   "contains(('flight', 'due'))": False,
#   "contains(('flight', 'experience'))": False,
#   "contains(('flights', 'Cancelled'))": False,
#   "contains(('flights', 'SouthwestAir'))": False,
#   "contains(('flying', 'experience'))": False,
#   "contains(('frequent', 'flyer'))": False,
#   "contains(('great', 'service'))": False,
#   "contains(('home', 'AmericanAir'))": False,
#   "contains(('home', 'united'))": False,
#   "contains(('look', 'forward'))": False,
#   "contains(('middle', 'seat'))": False,
#   "contains(('miss', 'connection'))": False,
#   "contains(('real', 'person'))": False,
#   "contains(('response', 'USAirways'))": False,
#   "contains(('seems', 'like'))": False,
#   "contains(('someone', 'please'))": False,
#   "contains(('status', 'match'))": False,
#   "contains(('take', 'care'))": False,
#   "contains(('tell', 'us'))": False,
#   "contains(('terrible', 'customer'))": False,
#   "contains(('time', 'amp'))": False,
#   "contains(('today', 'SouthwestAir'))": False,
#   "contains(('tonight', 'USAirways'))": False,
#   "contains(('trip', 'united'))": False,
#   "contains(('u', 'guys'))": False,
#   "contains(('u', 'help'))": False,
#   "contains(('united', 'That'))": False,
#   "contains(('united', 'We'))": False,
#   "contains(('united', 'ok'))": False,
#   "contains(('united', 'worst'))": False,
#   "contains(('us', 'airways'))": False,
#   "contains(('us', 'home'))": False,
#   "contains(('yet', 'united'))": False,
#   "contains(('American', 'http'))": False,
#   "contains(('AmericanAir', 'Not'))": False,
#   "contains(('AmericanAir', 'ok'))": False,
#   "contains(('AmericanAir', 'still'))": False,
#   "contains(('Flight', 'JetBlue'))": False,
#   "contains(('Flight', 'SouthwestAir'))": False,
#   "contains(('Flight', 'united'))": False,
#   "contains(('Great', 'service'))": False,
#   "contains(('Help', 'USAirways'))": False,
#   "contains(('JetBlue', 'No'))": False,
#   "contains(('JetBlue', 'Why'))": False,
#   "contains(('JetBlue', 'great'))": False,
#   "contains(('Not', 'cool'))": False,
#   "contains(('Not', 'even'))": False,
#   "contains(('Not', 'sure'))": False,
#   "contains(('SouthwestAir', 'Any'))": False,
#   "contains(('SouthwestAir', 'Cancelled'))": False,
#   "contains(('SouthwestAir', 'What'))": False,
#   "contains(('SouthwestAir', 'love_dragonss'))": False,
#   "contains(('USAirways', 'So'))": False,
#   "contains(('USAirways', 'We'))": False,
#   "contains(('VirginAmerica', 'thanks'))": False,
#   "contains(('You', 'Cancelled'))": False,
#   "contains(('automated', 'system'))": False,
#   "contains(('bag', 'USAirways'))": False,
#   "contains(('change', 'fees'))": False,
#   "contains(('change', 'flight'))": False,
#   "contains(('days', 'ago'))": False,
#   "contains(('even', 'let'))": False,
#   "contains(('exit', 'row'))": False,
#   "contains(('final', 'destination'))": False,
#   "contains(('flight', 'change'))": False,
#   "contains(('flight', 'status'))": False,
#   "contains(('fly', 'united'))": False,
#   "contains(('gate', 'changes'))": False,
#   "contains(('get', 'tickets'))": False,
#   "contains(('getting', 'back'))": False,
#   "contains(('guys', 'rock'))": False,
#   "contains(('help', 'VirginAmerica'))": False,
#   "contains(('hours', 'AmericanAir'))": False,
#   "contains(('hours', 'waiting'))": False,
#   "contains(('hr', 'delay'))": False,
#   "contains(('live', 'person'))": False,
#   "contains(('maintenance', 'issues'))": False,
#   "contains(('many', 'times'))": False,
#   "contains(('mechanical', 'problems'))": False,
#   "contains(('minute', 'wait'))": False,
#   "contains(('money', 'back'))": False,
#   "contains(('multiple', 'times'))": False,
#   "contains(('need', 'assistance'))": False,
#   "contains(('next', 'week'))": False,
#   "contains(('nothing', 'AmericanAir'))": False,
#   "contains(('nothing', 'united'))": False,
#   "contains(('one', 'hour'))": False,
#   "contains(('pass', 'united'))": False,
#   "contains(('phone', 'call'))": False,
#   "contains(('please', 'SouthwestAir'))": False,
#   "contains(('please', 'follow'))": False,
#   "contains(('ridiculous', 'USAirways'))": False,
#   "contains(('service', 'experience'))": False,
#   "contains(('service', 'sucks'))": False,
#   "contains(('taken', 'care'))": False,
#   "contains(('today', 'USAirways'))": False,
#   "contains(('tomorrow', 'SouthwestAir'))": False,
#   "contains(('travel', 'experience'))": False,
#   "contains(('two', 'weeks'))": False,
#   "contains(('united', 'If'))": False,
#   "contains(('united', 'Not'))": False,
#   "contains(('united', 'So'))": False,
#   "contains(('united', 'This'))": False,
#   "contains(('united', 'really'))": False,
#   "contains(('via', 'phone'))": False,
#   "contains(('w', 'u'))": False,
#   "contains(('would', 'go'))": False,
#   "contains(('would', 'help'))": False,
#   "contains(('yes', 'please'))": False,
#   "contains(('1st', 'flight'))": False,
#   "contains(('AmericanAir', 'Is'))": False,
#   "contains(('AmericanAir', 'Please'))": False,
#   "contains(('AmericanAir', 'This'))": False,
#   "contains(('AmericanAir', 'Trying'))": False,
#   "contains(('AmericanAir', 'Why'))": False,
#   "contains(('AmericanAir', 'hey'))": False,
#   "contains(('AmericanAir', 'trying'))": False,
#   "contains(('Can', 'u'))": False,
#   "contains(('DestinationDragons', 'united'))": False,
#   "contains(('Dividend', 'Miles'))": False,
#   "contains(('Flight', 'USAirways'))": False,
#   "contains(('Flight', 'flights'))": False,
#   "contains(('Flighted', 'flights'))": False,
#   "contains(('Flightled', 'AmericanAir'))": False,
#   "contains(('Help', 'SouthwestAir'))": False,
#   "contains(('JetBlue', 'If'))": False,
#   "contains(('JetBlue', 'We'))": False,
#   "contains(('Late', 'Flightly'))": False,
#   "contains(('No', 'worries'))": False,
#   "contains(('Republican', 'American'))": False,
#   "contains(('SouthwestAir', 'Imaginedragons'))": False,
#   "contains(('SouthwestAir', 'Your'))": False,
#   "contains(('SouthwestAir', 'got'))": False,
#   "contains(('Still', 'waiting'))": False,
#   "contains(('Street', 'Waterbury'))": False,
#   "contains(('Terrible', 'customer'))": False,
#   "contains(('Thank', 'You'))": False,
#   "contains(('USAirways', 'Yes'))": False,
#   "contains(('VirginAmerica', 'ladygaga'))": False,
#   "contains(('Waterbury', 'Republican'))": False,
#   "contains(('Would', 'love'))": False,
#   "contains(('airline', 'AmericanAir'))": False,
#   "contains(('amp', 'got'))": False,
#   "contains(('amp', 'still'))": False,
#   "contains(('back', 'united'))": False,
#   "contains(('bag', 'SouthwestAir'))": False,
#   "contains(('best', 'AmericanAir'))": False,
#   "contains(('call', 'customer'))": False,
#   "contains(('could', 'use'))": False,
#   "contains(('delayed', 'SouthwestAir'))": False,
#   "contains(('e', 'mail'))": False,
#   "contains(('early', 'bird'))": False,
#   "contains(('error', 'message'))": False,
#   "contains(('ever', 'experienced'))": False,
#   "contains(('ever', 'seen'))": False,
#   "contains(('fail', 'JetBlue'))": False,
#   "contains(('fail', 'SouthwestAir'))": False,
#   "contains(('flight', 'VirginAmerica'))": False,
#   "contains(('flight', 'http'))": False,
#   "contains(('flight', 'info'))": False,
#   "contains(('flight', 'number'))": False,
#   "contains(('flights', 'united'))": False,
#   "contains(('fly', 'w'))": False,
#   "contains(('get', 'help'))": False,
#   "contains(('getting', 'us'))": False,
#   "contains(('got', 'us'))": False,
#   "contains(('ground', 'staff'))": False,
#   "contains(('guys', 'USAirways'))": False,
#   "contains(('home', 'today'))": False,
#   "contains(('ladygaga', 'carrieunderwood'))": False,
#   "contains(('long', 'day'))": False,
#   "contains(('look', 'like'))": False,
#   "contains(('lost', 'luggage'))": False,
#   "contains(('morning', 'AmericanAir'))": False,
#   "contains(('much', 'better'))": False,
#   "contains(('new', 'plane'))": False,
#   "contains(('non', 'existent'))": False,
#   "contains(('one', 'answers'))": False,
#   "contains(('paying', 'customers'))": False,
#   "contains(('people', 'working'))": False,
#   "contains(('phone', 'line'))": False,
#   "contains(('plane', 'USAirways'))": False,
#   "contains(('please', 'get'))": False,
#   "contains(('please', 'please'))": False,
#   "contains(('problem', 'united'))": False,
#   "contains(('rental', 'car'))": False,
#   "contains(('seat', 'assignment'))": False,
#   "contains(('shit', 'together'))": False,
#   "contains(('terrible', 'service'))": False,
#   "contains(('though', 'AmericanAir'))": False,
#   "contains(('ticket', 'counter'))": False,
#   "contains(('tonight', 'united'))": False,
#   "contains(('tried', 'calling'))": False,
#   "contains(('united', 'Do'))": False,
#   "contains(('united', 'Is'))": False,
#   "contains(('united', 'Please'))": False,
#   "contains(('united', 'Will'))": False,
#   "contains(('us', 'air'))": False,
#   "contains(('weather', 'delay'))": False,
#   "contains(('yr', 'old'))": False,
#   "contains(('1st', 'time'))": False,
#   "contains(('AmericanAir', 'Hey'))": False,
#   "contains(('AmericanAir', 'Just'))": False,
#   "contains(('AmericanAir', 'What'))": False,
#   "contains(('AmericanAir', 'dfwairport'))": False,
#   "contains(('AmericanAir', 'got'))": False,
#   "contains(('Flightled', 'Can'))": False,
#   "contains(('Flightled', 'due'))": False,
#   "contains(('Flightled', 'yesterday'))": False,
#   "contains(('Flightr', 'still'))": False,
#   "contains(('How', 'many'))": False,
#   "contains(('Imagine', 'Dragons'))": False,
#   "contains(('It', 'says'))": False,
#   "contains(('JetBlue', 'Hey'))": False,
#   "contains(('JetBlue', 'Just'))": False,
#   "contains(('JetBlue', 'ok'))": False,
#   "contains(('Late', 'Flightst'))": False,
#   "contains(('My', 'bag'))": False,
#   "contains(('Not', 'good'))": False,
#   "contains(('Our', 'flight'))": False,
#   "contains(('Palm', 'Springs'))": False,
#   "contains(('San', 'Francisco'))": False,
#   "contains(('SouthwestAir', 'No'))": False,
#   "contains(('SouthwestAir', 'So'))": False,
#   "contains(('SouthwestAir', 'We'))": False,
#   "contains(('SouthwestAir', 'Why'))": False,
#   "contains(('SouthwestAir', 'great'))": False,
#   "contains(('SouthwestAir', 'oh'))": False,
#   "contains(('SouthwestAir', 'sent'))": False,
#   "contains(('They', 'said'))": False,
#   "contains(('Thx', 'AmericanAir'))": False,
#   "contains(('Too', 'bad'))": False,
#   "contains(('USAirways', 'This'))": False,
#   "contains(('USAirways', 'delayed'))": False,
#   "contains(('USAirways', 'flights'))": False,
#   "contains(('USAirways', 'never'))": False,
#   "contains(('USAirways', 'really'))": False,
#   "contains(('USAirways', 'stuck'))": False,
#   "contains(('USAirways', 'united'))": False,
#   "contains(('USAirways', 'well'))": False,
#   "contains(('USAirways', 'would'))": False,
#   "contains(('VirginAmerica', 'Thanks'))": False,
#   "contains(('VirginAmerica', 'You'))": False,
#   "contains(('Was', 'told'))": False,
#   "contains(('act', 'together'))": False,
#   "contains(('admirals', 'club'))": False,
#   "contains(('app', 'says'))": False,
#   "contains(('available', 'united'))": False,
#   "contains(('back', 'JetBlue'))": False,
#   "contains(('bad', 'experience'))": False,
#   "contains(('cabin', 'crew'))": False,
#   "contains(('call', 'AmericanAir'))": False,
#   "contains(('care', 'less'))": False,
#   "contains(('change', 'flights'))": False,
#   "contains(('checked', 'baggage'))": False,
#   "contains(('come', 'back'))": False,
#   "contains(('day', 'Late'))": False,
#   "contains(('days', 'Late'))": False,
#   "contains(('de', 'ice'))": False,
#   "contains(('different', 'flight'))": False,
#   "contains(('economy', 'plus'))": False,
#   "contains(('empty', 'seats'))": False,
#   "contains(('every', 'week'))": False,
#   "contains(('existing', 'reservation'))": False,
#   "contains(('favorite', 'airline'))": False,
#   "contains(('flight', 'Can'))": False,
#   "contains(('flight', 'ever'))": False,
#   "contains(('follow', 'back'))": False,
#   "contains(('free', 'wifi'))": False,
#   "contains(('full', 'flight'))": False,
#   "contains(('gate', 'SouthwestAir'))": False,
#   "contains(('gate', 'USAirways'))": False,
#   "contains(('get', 'another'))": False,
#   "contains(('getting', 'Cancelled'))": False,
#   "contains(('go', 'SouthwestAir'))": False,
#   "contains(('got', 'disconnected'))": False,
#   "contains(('got', 'rebooked'))": False,
#   "contains(('guys', 'JetBlue'))": False,
#   "contains(('guys', 'suck'))": False,
#   "contains(('hold', 'AmericanAir'))": False,
#   "contains(('home', 'tonight'))": False,
#   "contains(('horrible', 'customer'))": False,
#   "contains(('hotel', 'voucher'))": False,
#   "contains(('hour', 'ago'))": False,
#   "contains(('hour', 'delayed'))": False,
#   "contains(('hour', 'united'))": False,
#   "contains(('hour', 'waiting'))": False,
#   "contains(('hours', 'SouthwestAir'))": False,
#   "contains(('info', 'USAirways'))": False,
#   "contains(('info', 'united'))": False,
#   "contains(('last', 'month'))": False,
#   "contains(('lost', 'amp'))": False,
#   "contains(('love', 'flying'))": False,
#   "contains(('making', 'us'))": False,
#   "contains(('mileage', 'plus'))": False,
#   "contains(('min', 'wait'))": False,
#   "contains(('minute', 'delay'))": False,
#   "contains(('minutes', 'AmericanAir'))": False,
#   "contains(('missed', 'connections'))": False,
#   "contains(('much', 'united'))": False,
#   "contains(('one', 'day'))": False,
#   "contains(('plane', 'AmericanAir'))": False,
#   "contains(('power', 'outlets'))": False,
#   "contains(('pre', 'check'))": False,
#   "contains(('really', 'need'))": False,
#   "contains(('rescheduled', 'flight'))": False,
#   "contains(('reservation', 'online'))": False,
#   "contains(('response', 'AmericanAir'))": False,
#   "contains(('response', 'united'))": False,
#   "contains(('right', 'thing'))": False,
#   "contains(('second', 'time'))": False,
#   "contains(('see', 'Imaginedragons'))": False,
#   "contains(('sent', 'USAirways'))": False,
#   "contains(('service', 'amp'))": False,
#   "contains(('snow', 'storm'))": False,
#   "contains(('taking', 'care'))": False,
#   "contains(('times', 'united'))": False,
#   "contains(('united', 'Cancelled'))": False,
#   "contains(('united', 'On'))": False,
#   "contains(('united', 'USAirways'))": False,
#   "contains(('united', 'customer'))": False,
#   "contains(('united', 'hi'))": False,
#   "contains(('united', 'nope'))": False,
#   "contains(('united', 'tried'))": False,
#   "contains(('way', 'united'))": False,
#   "contains(('weather', 'delays'))": False,
#   "contains(('week', 'united'))": False,
#   "contains(('work', 'tomorrow'))": False,
#   "contains(('would', 'appreciate'))": False,
#   "contains(('would', 'make'))": False,
#   "contains(('would', 'rather'))": False,
#   "contains(('would', 'think'))": False,
#   "contains(('3rd', 'time'))": False,
#   "contains(('Airport', 'http'))": False,
#   "contains(('AmericanAir', 'That'))": False,
#   "contains(('AmericanAir', 'great'))": False,
#   "contains(('AmericanAir', 'thx'))": False,
#   "contains(('AmericanAir', 'well'))": False,
#   "contains(('Been', 'waiting'))": False,
#   "contains(('First', 'Class'))": False,
#   "contains(('Flight', 'crew'))": False,
#   "contains(('Flightled', 'today'))": False,
#   "contains(('Flightling', 'flights'))": False,
#   "contains(('Flightr', 'flight'))": False,
#   "contains(('Fort', 'Lauderdale'))": False,
#   "contains(('Is', 'flight'))": False,
#   "contains(('JetBlue', 'AmericanAir'))": False,
#   "contains(('JetBlue', 'Are'))": False,
#   "contains(('JetBlue', 'It'))": False,
#   "contains(('JetBlue', 'SouthwestAir'))": False,
#   "contains(('JetBlue', 'When'))": False,
#   "contains(('Just', 'wanted'))": False,
#   "contains(('No', 'way'))": False,
#   "contains(('Please', 'advise'))": False,
#   "contains(('Please', 'follow'))": False,
#   "contains(('Please', 'get'))": False,
#   "contains(('Puerto', 'Rico'))": False,
#   "contains(('Really', 'USAirways'))": False,
#   "contains(('So', 'far'))": False,
#   "contains(('SouthwestAir', 'Do'))": False,
#   "contains(('SouthwestAir', 'Great'))": False,
#   "contains(('SouthwestAir', 'On'))": False,
#   "contains(('SouthwestAir', 'Please'))": False,
#   "contains(('SouthwestAir', 'When'))": False,
#   "contains(('SouthwestAir', 'You'))": False,
#   "contains(('SouthwestAir', 'still'))": False,
#   "contains(('SouthwestAir', 'would'))": False,
#   "contains(('SouthwestAir', 'yeah'))": False,
#   "contains(('St', 'Louis'))": False,
#   "contains(('Terrible', 'service'))": False,
#   "contains(('USAirways', 'Good'))": False,
#   "contains(('USAirways', 'JetBlue'))": False,
#   "contains(('USAirways', 'PHLAirport'))": False,
#   "contains(('USAirways', 'That'))": False,
#   "contains(('USAirways', 'Why'))": False,
#   "contains(('USAirways', 'great'))": False,
#   "contains(('USAirways', 'trying'))": False,
#   "contains(('Very', 'disappointed'))": False,
#   "contains(('Very', 'frustrating'))": False,
#   "contains(('We', 'hope'))": False,
#   "contains(('Worst', 'customer'))": False,
#   "contains(('You', 'could'))": False,
#   "contains(('You', 'know'))": False,
#   "contains(('You', 'need'))": False,
#   "contains(('Your', 'airline'))": False,
#   "contains(('Your', 'crew'))": False,
#   "contains(('agent', 'said'))": False,
#   "contains(('airline', 'SouthwestAir'))": False,
#   "contains(('another', 'plane'))": False,
#   "contains(('anything', 'like'))": False,
#   "contains(('appreciated', 'united'))": False,
#   "contains(('bag', 'check'))": False,
#   "contains(('baggage', 'office'))": False,
#   "contains(('best', 'customer'))": False,
#   "contains(('best', 'flight'))": False,
#   "contains(('better', 'SouthwestAir'))": False,
#   "contains(('better', 'service'))": False,
#   "contains(('better', 'united'))": False,
#   "contains(('book', 'online'))": False,
#   "contains(('class', 'seat'))": False,
#   "contains(('confirmation', 'email'))": False,
#   "contains(('connection', 'USAirways'))": False,
#   "contains(('cool', 'united'))": False,
#   "contains(('country', 'flight'))": False,
#   "contains(('crew', 'member'))": False,
#   "contains(('cust', 'svc'))": False,
#   "contains(('customer', 'experience'))": False,
#   "contains(('customer', 'support'))": False,
#   "contains(('customers', 'USAirways'))": False,
#   "contains(('days', 'united'))": False,
#   "contains(('delay', 'AmericanAir'))": False,
#   "contains(('delay', 'JetBlue'))": False,
#   "contains(('entire', 'day'))": False,
#   "contains(('entire', 'flight'))": False,
#   "contains(('ever', 'USAirways'))": False,
#   "contains(('ever', 'united'))": False,
#   "contains(('every', 'single'))": False,
#   "contains(('everyone', 'else'))": False,
#   "contains(('excellent', 'customer'))": False,
#   "contains(('experience', 'USAirways'))": False,
#   "contains(('fail', 'AmericanAir'))": False,
#   "contains(('first', 'place'))": False,
#   "contains(('flight', 'It'))": False,
#   "contains(('flight', 'leaves'))": False,
#   "contains(('flight', 'online'))": False,
#   "contains(('flight', 'tonight'))": False,
#   "contains(('flights', 'USAirways'))": False,
#   "contains(('fly', 'Southwest'))": False,
#   "contains(('fly', 'United'))": False,
#   "contains(('frustrated', 'united'))": False,
#   "contains(('gate', 'JetBlue'))": False,
#   "contains(('gate', 'attendant'))": False,
#   "contains(('get', 'Cancelled'))": False,
#   "contains(('get', 'ahold'))": False,
#   "contains(('get', 'hung'))": False,
#   "contains(('getting', 'worse'))": False,
#   "contains(('gives', 'USAirways'))": False,
#   "contains(('good', 'SouthwestAir'))": False,
#   "contains(('good', 'enough'))": False,
#   "contains(('good', 'luck'))": False,
#   "contains(('great', 'JetBlue'))": False,
#   "contains(('great', 'crew'))": False,
#   "contains(('great', 'united'))": False,
#   "contains(('guys', 'SouthwestAir'))": False,
#   "contains(('guys', 'need'))": False,
#   "contains(('heard', 'back'))": False,
#   "contains(('high', 'call'))": False,
#   "contains(('hold', 'since'))": False,
#   "contains(('hold', 'united'))": False,
#   "contains(('hold', 'w'))": False,
#   "contains(('home', 'JetBlue'))": False,
#   "contains(('home', 'SouthwestAir'))": False,
#   "contains(('horrible', 'experience'))": False,
#   "contains(('hotel', 'room'))": False,
#   "contains(('hour', 'AmericanAir'))": False,
#   "contains(('hour', 'trying'))": False,
#   "contains(('hr', 'wait'))": False,
#   "contains(('information', 'united'))": False,
#   "contains(('jetblue', 'http'))": False,
#   "contains(('little', 'help'))": False,
#   "contains(('load', 'bags'))": False,
#   "contains(('lol', 'united'))": False,
#   "contains(('long', 'way'))": False,
#   "contains(('lost', 'baggage'))": False,
#   "contains(('loyal', 'customer'))": False,
#   "contains(('luggage', 'SouthwestAir'))": False,
#   "contains(('meal', 'voucher'))": False,
#   "contains(('min', 'delay'))": False,
#   "contains(('minutes', 'early'))": False,
#   "contains(('morning', 'USAirways'))": False,
#   "contains(('never', 'received'))": False,
#   "contains(('new', 'ticket'))": False,
#   "contains(('number', 'united'))": False,
#   "contains(('one', 'knows'))": False,
#   "contains(('one', 'united'))": False,
#   "contains(('phone', 'USAirways'))": False,
#   "contains(('plane', 'ticket'))": False,
#   "contains(('please', 'JetBlue'))": False,
#   "contains(('please', 'call'))": False,
#   "contains(('please', 'passengers'))": False,
#   "contains(('please', 'tell'))": False,
#   "contains(('please', 'united'))": False,
#   "contains(('prompt', 'response'))": False,
#   "contains(('put', 'us'))": False,
#   "contains(('r', 'u'))": False,
#   "contains(('really', 'appreciate'))": False,
#   "contains(('record', 'locator'))": False,
#   "contains(('reservation', 'JetBlue'))": False,
#   "contains(('reservation', 'USAirways'))": False,
#   "contains(('reservation', 'united'))": False,
#   "contains(('response', 'JetBlue'))": False,
#   "contains(('ridiculous', 'SouthwestAir'))": False,
#   "contains(('right', 'SouthwestAir'))": False,
#   "contains(('right', 'balance'))": False,
#   "contains(('seats', 'available'))": False,
#   "contains(('second', 'flight'))": False,
#   "contains(('service', 'team'))": False,
#   "contains(('since', 'last'))": False,
#   "contains(('since', 'yesterday'))": False,
#   "contains(('soon', 'SouthwestAir'))": False,
#   "contains(('still', 'nothing'))": False,
#   "contains(('telling', 'us'))": False,
#   "contains(('three', 'hour'))": False,
#   "contains(('today', 'JetBlue'))": False,
#   "contains(('today', 'Thanks'))": False,
#   "contains(('tomorrow', 'JetBlue'))": False,
#   "contains(('tonight', 'AmericanAir'))": False,
#   "contains(('took', 'care'))": False,
#   "contains(('u', 'Cancelled'))": False,
#   "contains(('united', 'also'))": False,
#   "contains(('united', 'hey'))": False,
#   "contains(('united', 'seriously'))": False,
#   "contains(('update', 'AmericanAir'))": False,
#   "contains(('us', 'united'))": False,
#   "contains(('way', 'back'))": False,
#   "contains(('whole', 'day'))": False,
#   "contains(('worst', 'service'))": False,
#   "contains(('yet', 'USAirways'))": False,
#   "contains(('Airways', 'Corporation'))": False,
#   "contains(('AmericanAir', 'Also'))": False,
#   "contains(('AmericanAir', 'Do'))": False,
#   "contains(('AmericanAir', 'If'))": False,
#   "contains(('AmericanAir', 'Oh'))": False,
#   "contains(('AmericanAir', 'When'))": False,
#   "contains(('AmericanAir', 'hi'))": False,
#   "contains(('AmericanAir', 'oh'))": False,
#   "contains(('AmericanAir', 'really'))": False,
#   "contains(('AmericanAir', 'u'))": False,
#   "contains(('AmericanAir', 'worst'))": False,
#   "contains(('AmericanAir', 'would'))": False,
#   "contains(('Bad', 'weather'))": False,
#   "contains(('Been', 'trying'))": False,
#   "contains(('Costa', 'Rica'))": False,
#   "contains(('Delta', 'JetBlue'))": False,
#   "contains(('Delta', 'SouthwestAir'))": False,
#   "contains(('DestinationDragons', 'USAirways'))": False,
#   "contains(('Every', 'time'))": False,
#   "contains(('Finally', 'got'))": False,
#   "contains(('First', 'class'))": False,
#   "contains(('Flight', 'delayed'))": False,
#   "contains(('Flighted', 'due'))": False,
#   "contains(('Flighted', 'united'))": False,
#   "contains(('Flighting', 'flights'))": False,
#   "contains(('Flightr', 'AmericanAir'))": False,
#   "contains(('Flightr', 'USAirways'))": False,
#   "contains(('Flightr', 'united'))": False,
#   "contains(('Gate', 'agent'))": False,
#   "contains(('Imaginedragons', 'DestinationDragons'))": False,
#   "contains(('Imaginedragons', 'show'))": False,
#   "contains(('It', 'would'))": False,
#   "contains(('JetBlue', 'Can'))": False,
#   "contains(('JetBlue', 'Is'))": False,
#   "contains(('JetBlue', 'My'))": False,
#   "contains(('JetBlue', 'USAirways'))": False,
#   "contains(('JetBlue', 'hi'))": False,
#   "contains(('JetBlue', 'oh'))": False,
#   "contains(('JetBlue', 'okay'))": False,
#   "contains(('JetBlue', 'u'))": False,
#   "contains(('Just', 'landed'))": False,
#   "contains(('Love', 'Field'))": False,
#   "contains(('Much', 'appreciated'))": False,
#   "contains(('Never', 'flying'))": False,
#   "contains(('No', 'answer'))": False,
#   "contains(('Please', 'let'))": False,
#   "contains(('Pls', 'help'))": False,
#   "contains(('San', 'Jose'))": False,
#   "contains(('SouthwestAir', 'All'))": False,
#   "contains(('SouthwestAir', 'Hey'))": False,
#   "contains(('SouthwestAir', 'That'))": False,
#   "contains(('SouthwestAir', 'could'))": False,
#   "contains(('SouthwestAir', 'flying'))": False,
#   "contains(('SouthwestAir', 'love'))": False,
#   "contains(('SouthwestAir', 'really'))": False,
#   "contains(('SouthwestAir', 'sure'))": False,
#   "contains(('SouthwestAir', 'thx'))": False,
#   "contains(('SouthwestAir', 'trying'))": False,
#   "contains(('Thank', 'u'))": False,
#   "contains(('Thanks', 'VirginAmerica'))": False,
#   "contains(('The', 'website'))": False,
#   "contains(('Too', 'Late'))": False,
#   "contains(('USAirways', 'Been'))": False,
#   "contains(('USAirways', 'If'))": False,
#   "contains(('USAirways', 'Just'))": False,
#   "contains(('USAirways', 'On'))": False,
#   "contains(('USAirways', 'The'))": False,
#   "contains(('USAirways', 'They'))": False,
#   "contains(('USAirways', 'Will'))": False,
#   "contains(('USAirways', 'flt'))": False,
#   "contains(('USAirways', 'ok'))": False,
#   "contains(('USAirways', 'sitting'))": False,
#   "contains(('Unacceptable', 'united'))": False,
#   "contains(('United', 'Club'))": False,
#   "contains(('UnitedAirlines', 'SouthwestAir'))": False,
#   "contains(('VirginAmerica', 'Is'))": False,
#   "contains(('VirginAmerica', 'thank'))": False,
#   "contains(('We', 'need'))": False,
#   "contains(('What', 'happened'))": False,
#   "contains(('Will', 'never'))": False,
#   "contains(('With', 'New'))": False,
#   "contains(('You', 'suck'))": False,
#   "contains(('Your', 'staff'))": False,
#   "contains(('Your', 'website'))": False,
#   "contains(('ago', 'united'))": False,
#   "contains(('air', 'united'))": False,
#   "contains(('airline', 'JetBlue'))": False,
#   "contains(('airline', 'VirginAmerica'))": False,
#   "contains(('airport', 'SouthwestAir'))": False,
#   "contains(('already', 'Cancelled'))": False,
#   "contains(('amazing', 'customer'))": False,
#   "contains(('among', 'teens'))": False,
#   "contains(('another', 'day'))": False,
#   "contains(('anyone', 'else'))": False,
#   ...},
#  'negative')

# %%
#checking the length of the featureset
#it should be the same than unigram, because we processed number of documents
#this is for verification
len(featuresets2)
# Out:
# 14640

# %%
#how we run the classifier to see if we get a good accuracy score
#all this is just to find out which feature is more informative to predict sentiment
#Naive Bayes classifier with 5-fold cross validation for training on sentiments using bigram features

kf = KFold(n_splits = 5)
sum = 0

for train, test in kf.split(featuresets2):
    train_data2 = np.array(featuresets2)[train]
    test_data2 = np.array(featuresets2)[test]
    classifier2 = nltk.NaiveBayesClassifier.train(train_data2)
    sum += nltk.classify.accuracy(classifier2, test_data2)

acc2 = sum/5

# %%
#accuracy of classifier2, bigrams

acc2
# Out:
# 0.6788251366120217

# %%
#Since the accuracy for unigrams is higher than bigrams, we'll use unigrams
#as a feature to train the classifier and pass the test set through it
#the test set is the Coronavirus dataset, whose tweets we want to predict sentiment

# %%
# determining the sentiments of the 1/4th of the comments using classifier1
# for debugging purposes, we use only 1/100 of the corpus
# but for the final experiment you should use at least 1/4 of it
# NOTE: WITH 1/4 OF THE SAMPLE THIS CODE TAKES 2 HOURS TO RUN

#creating emply lists to append the tweets to
pos_sent = []
neg_sent = []
neu_sent = []

#now we add information extracted from the tweets
#title = []
#author = []
#country = []

#and total values of positive, negative or neutral tweets
#all these lists will end up as columns in our csv file, created later on
total_pos = []
total_neg = []
total_neu = []

#iterating over the test file of tweets we crated at the very beginning of the notebook
#PLEASE EDIT THE NUMBER OF DOCUMENTS AS MENTIONED ABOVE
for i in range(0, int(len(test_set['text'])/1)):
    #extracting the text
    sentences = nltk.sent_tokenize(test_set['text'][i])
    #opening the counter to add up positive, negative, or neutral according to predicted labels
    pos_count = 0
    neg_count = 0
    neu_count = 0
    #using our first classifier, the one trained with unigram features
    for sents in sentences:
        senti = classifier.classify(document_features(nltk.word_tokenize(sents), word_features))
        #adding items to the counter as they are classified
        if senti == 'positive':
            pos_sent.append(sents)
            pos_count += 1

        elif senti == 'negative':
            neg_sent.append(sents)
            neg_count += 1
    
        else:
            neu_sent.append(sents)
            neu_count += 1
    #appending the information from each sentence to the corresponding list       
    #title.append(test_set['title'][i])
    #author.append(test_set['author'][i])
    #country.append(test_set['country'][i])
    #appending the totals
    total_pos.append(pos_count)
    total_neg.append(neg_count)
    total_neu.append(neu_count)

# %%
len(test_set)
# Out:
# 2477.0

# %%
#how many positive sentiment sentences did we predict?
len(pos_sent)
# Out:
# 1296

# %%
#and how many negative sentiment ones?
len(neg_sent)
# Out:
# 588

# %%
#what about neutral?
len(neu_sent)
# Out:
# 1094

# %%
#WE ARE DONE WITH PREDICTIONS
#WE WILL ZOOM IN ON INFORMATIVE FEATURES ACCORDING TO PART OF SPEECH TAGS
#FOCUSING ON ADJECTIVES, ADVERBS, NOUNS AND VERBS

# %%
#We tokenize and attach POS to each sentence in the Positive Sentences list

tokens_pos = [nltk.word_tokenize(sent) for sent in pos_sent]
tags_pos = [nltk.pos_tag(token) for token in tokens_pos]

# %%
#same for Negative Sentences

tokens_neg = [nltk.word_tokenize(sent) for sent in neg_sent]
tags_neg = [nltk.pos_tag(token) for token in tokens_neg]

# %%
#let's check that everything is okay. We print the first 3 Negative sentences
print(tags_neg[:3])
# Out:
# [[('Alice', 'NNP'), ('was', 'VBD'), ('beginning', 'VBG'), ('to', 'TO'), ('get', 'VB'), ('very', 'RB'), ('tired', 'JJ'), ('of', 'IN'), ('sitting', 'VBG'), ('by', 'IN'), ('her', 'PRP$'), ('sister', 'NN'), ('on', 'IN'), ('the', 'DT')], [('bank', 'NN'), (',', ','), ('and', 'CC'), ('of', 'IN'), ('having', 'VBG'), ('nothing', 'NN'), ('to', 'TO'), ('do', 'VB'), (':', ':'), ('once', 'RB'), ('or', 'CC'), ('twice', 'VB'), ('she', 'PRP'), ('had', 'VBD'), ('peeped', 'VBN'), ('into', 'IN')], [('the', 'DT'), ('book', 'NN'), ('her', 'PRP$'), ('sister', 'NN'), ('was', 'VBD'), ('reading', 'VBG'), (',', ','), ('but', 'CC'), ('it', 'PRP'), ('had', 'VBD'), ('no', 'DT'), ('pictures', 'NNS'), ('or', 'CC')]]

# %%
#what about the first 3 positive ones...
print(tags_pos[:3])
# Out:
# [[('Down', 'IN'), ('the', 'DT'), ('Rabbit-Hole', 'JJ')], [('So', 'IN'), ('she', 'PRP'), ('was', 'VBD'), ('considering', 'VBG'), ('in', 'IN'), ('her', 'PRP$'), ('own', 'JJ'), ('mind', 'NN'), ('(', '('), ('as', 'RB'), ('well', 'RB'), ('as', 'IN'), ('she', 'PRP'), ('could', 'MD'), (',', ','), ('for', 'IN'), ('the', 'DT')], [('hot', 'JJ'), ('day', 'NN'), ('made', 'VBD'), ('her', 'PRP$'), ('feel', 'JJ'), ('very', 'RB'), ('sleepy', 'JJ'), ('and', 'CC'), ('stupid', 'JJ'), (')', ')'), (',', ','), ('whether', 'IN'), ('the', 'DT'), ('pleasure', 'NN'), ('of', 'IN')]]

# %%
# CREATING FUNCTIONS TO REUSE CODE FOR RETRIEVING DIFFERENTE TYPES OF PHRASES

# We will apply this code to find ADJECTIVE PHRASES positive and negative sentences first
# after that, you will need to change the grammar and subtree label in the function to extract:
# ADVERB, NOUN, and VERB phrases, as stated in the Homework guidelines

# EXTRACTING ACCORDING TO A GRAMMAR ADJECTIVE PHRASES
# this is the code we reuse, passing the "tags_pos", "tags_neg" or "tags_neu" accordingly
def grammar_phrases(tags_sent):
    grammar_adjph = "ADJPH: {<RB.?>+<JJ.?>}" # REMEMBER TO EDI THIS GRAMMAR FOR ADVERBS & VERBS!
    chunk_parser_adj = nltk.RegexpParser(grammar_adjph)
    adjph_tags = []
    for sent in tags_sent:
        if len(sent) > 0:
            tree = chunk_parser_adj.parse(sent)
            for subtree in tree.subtrees():
                if subtree.label() == 'ADJPH': # THIS ALSO NEEDS EDITION FOR ADVERBS & VERBS
                    adjph_tags.append(subtree)
    return adjph_tags


# EXTRACTING ADJECTIVE PHRASES without POS tags, just the phrase
# we also reuse this but replacing the 'tagged_phrase' in each new case
def word_phrase(tagged_phrase):
    adjective_phrases = []
    for sent in tagged_phrase:
        temp = ''
        for w, t in sent:
            temp += w+ ' '    
        adjective_phrases.append(temp)
    return adjective_phrases


# RANKING BY FREQUENCY
# this is also a function to reuse
def get_frequency(phrases):
    phrases_frequency = nltk.FreqDist(phrases)
    return phrases_frequency.most_common(50)

# %%
# EXTRACTING POSITIVE PHRASES AND THEIR POS
adjph_pos = grammar_phrases(tags_pos)
print('Adjective phrases in positive sentences, with POS: ', adjph_pos[:3])

# EXTRACTING POSITIVE ADJECTIVE PHRASES (WORDS ONLY)
word_adjph_pos = word_phrase(adjph_pos)
print('First 10 adjective phrases in positive sentences: ', word_adjph_pos[:10])

# RANKING POSITIVE PHRASES BY FREQUENCY
most_common_adjph_pos = get_frequency(word_adjph_pos)
print("Top 50 adjective phrases in positive sentences: ", most_common_adjph_pos[:50])
# Out:
# Adjective phrases in positive sentences, with POS:  [Tree('ADJPH', [('very', 'RB'), ('sleepy', 'JJ')]), Tree('ADJPH', [('so', 'RB'), ('_very_', 'RB'), ('much', 'JJ')]), Tree('ADJPH', [('quite', 'RB'), ('natural', 'JJ')])]
# First 10 adjective phrases in positive sentences:  ['very sleepy ', 'so _very_ much ', 'quite natural ', 'very deep ', 'very likely ', 'very much ', 'too large ', 'too small ', 'much larger ', 'very few ']
# Top 50 adjective phrases in positive sentences:  [('so much ', 5), ('very curious ', 4), ('very much ', 3), ('very few ', 2), ('very good ', 2), ('always ready ', 2), ('very difficult ', 2), ('quite silent ', 2), ('so _very_ ', 2), ('not much ', 2), ('too much ', 2), ('very glad ', 2), ('very interesting ', 2), ('once more ', 2), ('very sleepy ', 1), ('so _very_ much ', 1), ('quite natural ', 1), ('very deep ', 1), ('very likely ', 1), ('too large ', 1), ('too small ', 1), ('much larger ', 1), ('really impossible ', 1), ('now only ten ', 1), ('too slippery ', 1), ('very small ', 1), ('quite surprised ', 1), ('quite dull ', 1), ('now more ', 1), ('very hot ', 1), ('very little ', 1), ('ever so many ', 1), ('too bad ', 1), ('curly brown ', 1), ('as hard ', 1), ('more energetic ', 1), ('soon left ', 1), ('as sure ', 1), ('much sooner ', 1), ('quite enough ', 1), ('quite so much ', 1), ('too late ', 1), ('very confusing.\x9d ', 1), ('very melancholy ', 1), ('very white ', 1), ('perfectly sure ', 1), ('very supple ', 1), ('as steady ', 1), ('very sudden ', 1), ('very truthful ', 1)]

# %%
# EXTRACTING Negative PHRASES AND THEIR neg
adjph_neg = grammar_phrases(tags_neg)
print('Adjective phrases in negative sentences, with POS: ', adjph_neg[:3])

# EXTRACTING POSITIVE ADJECTIVE PHRASES (WORDS ONLY)
word_adjph_neg = word_phrase(adjph_neg)
print('First 10 adjective phrases in negative sentences: ', word_adjph_neg[:10])

# RANKING POSITIVE PHRASES BY FREQUENCY
most_common_adjph_neg = get_frequency(word_adjph_neg)
print("Top 50 adjective phrases in negative sentences: ", most_common_adjph_neg[:50])
# Out:
# Adjective phrases in negative sentences, with POS:  [Tree('ADJPH', [('very', 'RB'), ('tired', 'JJ')]), Tree('ADJPH', [('so', 'RB'), ('_very_', 'JJ')]), Tree('ADJPH', [('no', 'RB'), ('longer', 'JJR')])]
# First 10 adjective phrases in negative sentences:  ['very tired ', 'so _very_ ', 'no longer ', 'very little ', 'almost certain ', 'very nice ', 'very fond ', 'so much ', 'very glad ', 'so small ']
# Top 50 adjective phrases in negative sentences:  [('so much ', 3), ('very little ', 2), ('very glad ', 2), ("n't very civil ", 2), ('very tired ', 1), ('so _very_ ', 1), ('no longer ', 1), ('almost certain ', 1), ('very nice ', 1), ('very fond ', 1), ('so small ', 1), ('so out-of-the-way ', 1), ('very clear ', 1), ('not easy ', 1), ('quite dry ', 1), ('very absurd ', 1), ('so grave ', 1), ('here poor ', 1), ('very uncomfortable ', 1), ('almost wish ', 1), ('together first ', 1), ('enough yet ” ', 1), ('very likely ', 1), ('quite tired ', 1), ('so many ', 1), ('too weak ', 1), ('more subdued ', 1), ('more puzzled ', 1), ('very sorry ', 1), ('so long ', 1), ('nearly as large ', 1), ('quite impossible ', 1), ('as much ', 1), ('neither more ', 1), ('quite absurd ', 1), ('not so mad ', 1), ('so large ', 1), ('so confused ', 1), ('Once more ', 1), ('rather doubtful ', 1), ('very uneasy ', 1), ('very hopeful ', 1), ('only wish ', 1), ('rather better ', 1), ('˜The more ', 1), ('simply ” ', 1), ('quite unhappy ', 1), ('so ordered ', 1), ('very long ', 1), ('too close ', 1)]

# %%
# EXTRACTING ACCORDING TO A GRAMMAR Adverb PHRASES
# this is the code we reuse, passing the "tags_pos", "tags_neg" or "tags_neu" accordingly
def grammar_phrases(tags_sent):
    grammar_advph = "ADVPH: {<RB>+<RB>}" # REMEMBER TO EDI THIS GRAMMAR FOR ADVERBS & VERBS!
    chunk_parser_adj = nltk.RegexpParser(grammar_advph)
    advph_tags = []
    for sent in tags_sent:
        if len(sent) > 0:
            tree = chunk_parser_adj.parse(sent)
            for subtree in tree.subtrees():
                if subtree.label() == 'ADVPH': # THIS ALSO NEEDS EDITION FOR ADVERBS & VERBS
                    advph_tags.append(subtree)
    return advph_tags


# EXTRACTING ADJECTIVE PHRASES without POS tags, just the phrase
# we also reuse this but replacing the 'tagged_phrase' in each new case
def word_phrase(tagged_phrase):
    adverb_phrases = []
    for sent in tagged_phrase:
        temp = ''
        for w, t in sent:
            temp += w+ ' '    
        adverb_phrases.append(temp)
    return adverb_phrases


# RANKING BY FREQUENCY
# this is also a function to reuse
def get_frequency(phrases):
    phrases_frequency = nltk.FreqDist(phrases)
    return phrases_frequency.most_common(50)

# %%
# EXTRACTING POSITIVE PHRASES AND THEIR POS
advph_pos = grammar_phrases(tags_pos)
print('Adverb phrases in positive sentences, with POS: ', advph_pos[:3])

# EXTRACTING POSITIVE ADJECTIVE PHRASES (WORDS ONLY)
word_advph_pos = word_phrase(advph_pos)
print('First 10 adverb phrases in positive sentences: ', word_advph_pos[:10])

# RANKING POSITIVE PHRASES BY FREQUENCY
most_common_advph_pos = get_frequency(word_advph_pos)
print("Top 50 adverb phrases in positive sentences: ", most_common_advph_pos[:50])
# Out:
# Adverb phrases in positive sentences, with POS:  [Tree('ADVPH', [('as', 'RB'), ('well', 'RB')]), Tree('ADVPH', [('so', 'RB'), ('_very_', 'RB')]), Tree('ADVPH', [('deep', 'RB'), ('well', 'RB')])]
# First 10 adverb phrases in positive sentences:  ['as well ', 'so _very_ ', 'deep well ', 'very slowly ', 'down here ', 'very earnestly ', 'not even ', 'very well ', 'so Alice ', 'very soon ']
# Top 50 adverb phrases in positive sentences:  [('as well ', 10), ('very soon ', 5), ('down here ', 3), ('As soon ', 3), ('very nearly ', 3), ('just as well ', 3), ('very much ', 3), ('very slowly ', 2), ('very earnestly ', 2), ('very well ', 2), ('too far ', 2), ('as hard ', 2), ('very politely ', 2), ('very gravely ', 2), ('very carefully ', 2), ('never even ', 2), ('as long ', 2), ('so often ', 2), ('so _very_ ', 1), ('deep well ', 1), ('not even ', 1), ('so Alice ', 1), ('now only ', 1), ('quite plainly ', 1), ('very seldom ', 1), ('so far ', 1), ('Just then ', 1), ('ever so ', 1), ('perhaps not ', 1), ('so nicely ', 1), ("n't indeed ", 1), ('rather crossly ', 1), ('very humbly ', 1), ('very angrily ', 1), ('so easily ', 1), ('as soon ', 1), ('slowly back again ', 1), ('very good-naturedly ', 1), ('Very soon ', 1), ('so indeed ', 1), ('quite so ', 1), ('better now ', 1), ('very neatly ', 1), ('so yet ', 1), ('very queer ', 1), ('back again ', 1), ('so awfully ', 1), ('rather doubtfully ', 1), ('down again ', 1), ('certainly there ', 1)]

# %%
# EXTRACTING Negative PHRASES AND THEIR POS
advph_neg = grammar_phrases(tags_neg)
print('Adverb phrases in negative sentences, with POS: ', advph_neg[:3])

# EXTRACTING Negative ADJECTIVE PHRASES (WORDS ONLY)
word_advph_neg = word_phrase(advph_neg)
print('First 10 adverb phrases in negative sentences: ', word_advph_neg[:10])

# RANKING POSITIVE PHRASES BY FREQUENCY
most_common_advph_neg = get_frequency(word_advph_neg)
print("Top 50 adverb phrases in negative sentences: ", most_common_advph_neg[:50])
# Out:
# Adverb phrases in negative sentences, with POS:  [Tree('ADVPH', [('never', 'RB'), ('before', 'RB')]), Tree('ADVPH', [('not', 'RB'), ('here', 'RB')]), Tree('ADVPH', [('too', 'RB'), ('long', 'RB')])]
# First 10 adverb phrases in negative sentences:  ['never before ', 'not here ', 'too long ', 'not possibly ', 'rather sharply ', 'up again ', 'alone here ', 'as nearly ', 'away altogether ', 'long ago ']
# Top 50 adverb phrases in negative sentences:  [('down again ', 2), ('very politely ', 2), ('so far ', 2), ("n't very ", 2), ('just now ', 2), ('never before ', 1), ('not here ', 1), ('too long ', 1), ('not possibly ', 1), ('rather sharply ', 1), ('up again ', 1), ('alone here ', 1), ('as nearly ', 1), ('away altogether ', 1), ('long ago ', 1), ('slowly back ', 1), ('well enough ', 1), ('very soon ', 1), ('not even ', 1), ('now here ', 1), ('enough yet ', 1), ('about again ', 1), ('not long ', 1), ('back again ', 1), ('as well wait ', 1), ('nearly as ', 1), ('very well ', 1), ('very much ', 1), ('not so ', 1), ('even then ', 1), ('very readily ', 1), ('asleep again ', 1), ('very angrily ', 1), ('very humbly ', 1), ('_there_ again ', 1), ("_You'd_ better not ", 1), ('angrily away ', 1), ('then quietly ', 1), ('down again very ', 1), ('certainly not ', 1), ('up very sulkily ', 1), ('now hastily ', 1), ('perhaps even ', 1)]

# %%
# EXTRACTING ACCORDING TO A GRAMMAR Adverb PHRASES
# this is the code we reuse, passing the "tags_pos", "tags_neg" or "tags_neu" accordingly
def grammar_phrases(tags_sent):
    grammar_vbph = "VBPH: {<VB.?>+<VB.?>}" # REMEMBER TO EDI THIS GRAMMAR FOR ADVERBS & VERBS!
    chunk_parser_adj = nltk.RegexpParser(grammar_vbph)
    vbph_tags = []
    for sent in tags_sent:
        if len(sent) > 0:
            tree = chunk_parser_adj.parse(sent)
            for subtree in tree.subtrees():
                if subtree.label() == 'VBPH': # THIS ALSO NEEDS EDITION FOR ADVERBS & VERBS
                    vbph_tags.append(subtree)
    return vbph_tags


# EXTRACTING ADJECTIVE PHRASES without POS tags, just the phrase
# we also reuse this but replacing the 'tagged_phrase' in each new case
def word_phrase(tagged_phrase):
    verb_phrases = []
    for sent in tagged_phrase:
        temp = ''
        for w, t in sent:
            temp += w+ ' '    
        verb_phrases.append(temp)
    return verb_phrases


# RANKING BY FREQUENCY
# this is also a function to reuse
def get_frequency(phrases):
    phrases_frequency = nltk.FreqDist(phrases)
    return phrases_frequency.most_common(50)

# %%
# EXTRACTING POSITIVE PHRASES AND THEIR POS
vbph_pos = grammar_phrases(tags_pos)
print('Verb phrases in positive sentences, with POS: ', vbph_pos[:3])

# EXTRACTING POSITIVE VERB PHRASES (WORDS ONLY)
word_vbph_pos = word_phrase(vbph_pos)
print('First 10 verb phrases in positive sentences: ', word_vbph_pos[:10])

# RANKING POSITIVE PHRASES BY FREQUENCY
most_common_vbph_pos = get_frequency(word_vbph_pos)
print("Top 50 verb phrases in positive sentences: ", most_common_vbph_pos[:50])
# Out:
# Verb phrases in positive sentences, with POS:  [Tree('VBPH', [('was', 'VBD'), ('considering', 'VBG')]), Tree('VBPH', [('were', 'VBD'), ('filled', 'VBN')]), Tree('VBPH', [('was', 'VBD'), ('labelled', 'VBN')])]
# First 10 verb phrases in positive sentences:  ['was considering ', 'were filled ', 'was labelled ', 'was dozing ', 'had begun ', 'had got ', 'having seen ', 'were getting ', 'be ashamed ', 'came trotting ']
# Top 50 verb phrases in positive sentences:  [('had been ', 6), ('had made ', 4), ("'ve seen ", 4), ('was talking ', 3), ('was getting ', 3), ('was looking ', 3), ("'ve tried ", 3), ('had got ', 2), ('were getting ', 2), ('was surprised ', 2), ('had come ', 2), ('was pressed ', 2), ("'ve got ", 2), ('have got ', 2), ('was sneezing ', 2), ("'re doing ", 2), ('were learning ', 2), ('was gone ', 2), ('was considering ', 1), ('were filled ', 1), ('was labelled ', 1), ('was dozing ', 1), ('had begun ', 1), ('having seen ', 1), ('be ashamed ', 1), ('came trotting ', 1), ("'ve been changed ", 1), ('is twelve ', 1), ('were saying ', 1), ('was shut ', 1), ('being drowned ', 1), ('_will_ be ', 1), ('remembered having seen ', 1), ('sits purring ', 1), ('was bristling ', 1), ('was trembling ', 1), ("'ve offended ", 1), ('was swimming ', 1), ('had known ', 1), ('had finished ', 1), ('be offended ', 1), ('began wrapping ', 1), ('be getting ', 1), ('began hunting ', 1), ('be seen ', 1), ('have changed ', 1), ('had vanished ', 1), ('went hunting ', 1), ('better take ', 1), ('had found ', 1)]

# %%
# EXTRACTING Negative PHRASES AND THEIR POS
vbph_neg = grammar_phrases(tags_neg)
print('Verb phrases in negative sentences, with POS: ', vbph_neg[:3])

# EXTRACTING Negative VERB PHRASES (WORDS ONLY)
word_vbph_neg = word_phrase(vbph_neg)
print('First 10 verb phrases in positive sentences: ', word_vbph_neg[:10])

# RANKING Negative PHRASES BY FREQUENCY
most_common_vbph_neg = get_frequency(word_vbph_neg)
print("Top 50 verb phrases in negative sentences: ", most_common_vbph_neg[:50])
# Out:
# Verb phrases in negative sentences, with POS:  [Tree('VBPH', [('was', 'VBD'), ('beginning', 'VBG')]), Tree('VBPH', [('had', 'VBD'), ('peeped', 'VBN')]), Tree('VBPH', [('was', 'VBD'), ('reading', 'VBG')])]
# First 10 verb phrases in positive sentences:  ['was beginning ', 'had peeped ', 'was reading ', "'ve got ", 'be lost ', "'s getting ", 'be seen ', 'was lit ', 'had been ', 'thought was ']
# Top 50 verb phrases in negative sentences:  [('was going ', 6), ('had been ', 5), ('was sitting ', 5), ('have been ', 4), ('was beginning ', 3), ('had got ', 3), ("'ve got ", 2), ('be lost ', 2), ("'s getting ", 2), ('has won ', 2), ('was delighted ', 2), ("'ve tried ", 2), ('had gone ', 2), ('was gone ', 2), ('was looking ', 2), ('be raving ', 2), ("'ve had ", 2), ('were trying ', 2), ('was obliged ', 2), ('had peeped ', 1), ('was reading ', 1), ('be seen ', 1), ('was lit ', 1), ('thought was ', 1), ('had taught ', 1), ('be shutting ', 1), ('had forgotten ', 1), ('had tired ', 1), ('remembered trying ', 1), ('have been changed ', 1), ('saying ˜Come ', 1), ('like being ', 1), ('had put ', 1), ('was holding ', 1), ('avoid shrinking ', 1), ('was lying ', 1), ('had fallen ', 1), ('be said ', 1), ('do it.\x9d ', 1), ('were placed ', 1), ('had been running ', 1), ('was speaking ', 1), ('had changed ', 1), ('had lost ', 1), ('have dropped ', 1), ('be turned ', 1), ('had found ', 1), ('had hoped ', 1), ('being broken ', 1), ('be afraid ', 1)]

# %%
# NOW, YOUR TURN!!
# USE THESE FUNCTIONS TO EXTRACT NEGATIVE PHRASES, CLEAN NEGATIVE ADJECTIVE PHRASES FROM POS,
# AND RANK NEGATIVE PHRASES BY FREQUENCY

# YOU ALSO NEED TO MODIFY THE GRAMMAR TO LOOK FOR:
# NOUNS
# VERBS
## IN BOTH CASES, DON'T FORGET THAT THERE ARE MANY TAGS IN EACH GROUP!!
##  CHECK THE PENN POS TAGS LIST: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

# %%
df1 = pd.DataFrame(list(zip(most_common_adjph_pos, most_common_adjph_neg, most_common_advph_pos, most_common_vbph_pos, most_common_vbph_neg)), 
                       columns = ['adjective phrase_pos', 'adjective phrase_neg','adverb phrase_pos','verb phrase_pos','verb phrase_neg'])

# %%
#printing the dataframe, to confirm everything is fine
df1
# Out:
#        adjective phrase_pos      adjective phrase_neg  \
# 0             (so much , 5)             (so much , 3)
# 1        (very curious , 4)         (very little , 2)
# 2           (very much , 3)           (very glad , 2)
# 3            (very few , 2)      (n't very civil , 2)
# 4           (very good , 2)          (very tired , 1)
# 5        (always ready , 2)           (so _very_ , 1)
# 6      (very difficult , 2)           (no longer , 1)
# 7        (quite silent , 2)      (almost certain , 1)
# 8           (so _very_ , 2)           (very nice , 1)
# 9            (not much , 2)           (very fond , 1)
# 10           (too much , 2)            (so small , 1)
# 11          (very glad , 2)   (so out-of-the-way , 1)
# 12   (very interesting , 2)          (very clear , 1)
# 13          (once more , 2)            (not easy , 1)
# 14        (very sleepy , 1)           (quite dry , 1)
# 15     (so _very_ much , 1)         (very absurd , 1)
# 16      (quite natural , 1)            (so grave , 1)
# 17          (very deep , 1)           (here poor , 1)
# 18        (very likely , 1)  (very uncomfortable , 1)
# 19          (too large , 1)         (almost wish , 1)
# 20          (too small , 1)      (together first , 1)
# 21        (much larger , 1)        (enough yet ” , 1)
# 22  (really impossible , 1)         (very likely , 1)
# 23       (now only ten , 1)         (quite tired , 1)
# 24       (too slippery , 1)             (so many , 1)
# 25         (very small , 1)            (too weak , 1)
# 26    (quite surprised , 1)        (more subdued , 1)
# 27         (quite dull , 1)        (more puzzled , 1)
# 28           (now more , 1)          (very sorry , 1)
# 29           (very hot , 1)             (so long , 1)
# 30        (very little , 1)     (nearly as large , 1)
# 31       (ever so many , 1)    (quite impossible , 1)
# 32            (too bad , 1)             (as much , 1)
# 33        (curly brown , 1)        (neither more , 1)
# 34            (as hard , 1)        (quite absurd , 1)
# 35     (more energetic , 1)          (not so mad , 1)
# 36          (soon left , 1)            (so large , 1)
# 37            (as sure , 1)         (so confused , 1)
# 38        (much sooner , 1)           (Once more , 1)
# 39       (quite enough , 1)     (rather doubtful , 1)
# 40      (quite so much , 1)         (very uneasy , 1)
# 41           (too late , 1)        (very hopeful , 1)
# 42   (very confusing. , 1)           (only wish , 1)
# 43    (very melancholy , 1)       (rather better , 1)
# 44         (very white , 1)           (˜The more , 1)
# 45     (perfectly sure , 1)            (simply ” , 1)
# 46        (very supple , 1)       (quite unhappy , 1)
# 47          (as steady , 1)          (so ordered , 1)
# 48        (very sudden , 1)           (very long , 1)
# 49      (very truthful , 1)           (too close , 1)
#
#             adverb phrase_pos               verb phrase_pos  \
# 0              (as well , 10)                (had been , 6)
# 1             (very soon , 5)                (had made , 4)
# 2             (down here , 3)                ('ve seen , 4)
# 3               (As soon , 3)             (was talking , 3)
# 4           (very nearly , 3)             (was getting , 3)
# 5          (just as well , 3)             (was looking , 3)
# 6             (very much , 3)               ('ve tried , 3)
# 7           (very slowly , 2)                 (had got , 2)
# 8        (very earnestly , 2)            (were getting , 2)
# 9             (very well , 2)           (was surprised , 2)
# 10              (too far , 2)                (had come , 2)
# 11              (as hard , 2)             (was pressed , 2)
# 12        (very politely , 2)                 ('ve got , 2)
# 13         (very gravely , 2)                (have got , 2)
# 14       (very carefully , 2)            (was sneezing , 2)
# 15           (never even , 2)               ('re doing , 2)
# 16              (as long , 2)           (were learning , 2)
# 17             (so often , 2)                (was gone , 2)
# 18            (so _very_ , 1)         (was considering , 1)
# 19            (deep well , 1)             (were filled , 1)
# 20             (not even , 1)            (was labelled , 1)
# 21             (so Alice , 1)              (was dozing , 1)
# 22             (now only , 1)               (had begun , 1)
# 23        (quite plainly , 1)             (having seen , 1)
# 24          (very seldom , 1)              (be ashamed , 1)
# 25               (so far , 1)           (came trotting , 1)
# 26            (Just then , 1)        ('ve been changed , 1)
# 27              (ever so , 1)               (is twelve , 1)
# 28          (perhaps not , 1)             (were saying , 1)
# 29            (so nicely , 1)                (was shut , 1)
# 30           (n't indeed , 1)           (being drowned , 1)
# 31       (rather crossly , 1)               (_will_ be , 1)
# 32          (very humbly , 1)  (remembered having seen , 1)
# 33         (very angrily , 1)            (sits purring , 1)
# 34            (so easily , 1)           (was bristling , 1)
# 35              (as soon , 1)           (was trembling , 1)
# 36    (slowly back again , 1)            ('ve offended , 1)
# 37  (very good-naturedly , 1)            (was swimming , 1)
# 38            (Very soon , 1)               (had known , 1)
# 39            (so indeed , 1)            (had finished , 1)
# 40             (quite so , 1)             (be offended , 1)
# 41           (better now , 1)          (began wrapping , 1)
# 42          (very neatly , 1)              (be getting , 1)
# 43               (so yet , 1)           (began hunting , 1)
# 44           (very queer , 1)                 (be seen , 1)
# 45           (back again , 1)            (have changed , 1)
# 46           (so awfully , 1)            (had vanished , 1)
# 47    (rather doubtfully , 1)            (went hunting , 1)
# 48           (down again , 1)             (better take , 1)
# 49      (certainly there , 1)               (had found , 1)
#
#             verb phrase_neg
# 0           (was going , 6)
# 1            (had been , 5)
# 2         (was sitting , 5)
# 3           (have been , 4)
# 4       (was beginning , 3)
# 5             (had got , 3)
# 6             ('ve got , 2)
# 7             (be lost , 2)
# 8          ('s getting , 2)
# 9             (has won , 2)
# 10      (was delighted , 2)
# 11          ('ve tried , 2)
# 12           (had gone , 2)
# 13           (was gone , 2)
# 14        (was looking , 2)
# 15          (be raving , 2)
# 16            ('ve had , 2)
# 17        (were trying , 2)
# 18        (was obliged , 2)
# 19         (had peeped , 1)
# 20        (was reading , 1)
# 21            (be seen , 1)
# 22            (was lit , 1)
# 23        (thought was , 1)
# 24         (had taught , 1)
# 25        (be shutting , 1)
# 26      (had forgotten , 1)
# 27          (had tired , 1)
# 28  (remembered trying , 1)
# 29  (have been changed , 1)
# 30       (saying ˜Come , 1)
# 31         (like being , 1)
# 32            (had put , 1)
# 33        (was holding , 1)
# 34    (avoid shrinking , 1)
# 35          (was lying , 1)
# 36         (had fallen , 1)
# 37            (be said , 1)
# 38            (do it. , 1)
# 39        (were placed , 1)
# 40   (had been running , 1)
# 41       (was speaking , 1)
# 42        (had changed , 1)
# 43           (had lost , 1)
# 44       (have dropped , 1)
# 45          (be turned , 1)
# 46          (had found , 1)
# 47          (had hoped , 1)
# 48       (being broken , 1)
# 49          (be afraid , 1)

# %%
df2 = pd.DataFrame(list(zip(most_common_advph_neg)), 
                       columns = ['adverb phrase_neg'])
df2
# Out:
#            adverb phrase_neg
# 0           (down again , 2)
# 1        (very politely , 2)
# 2               (so far , 2)
# 3             (n't very , 2)
# 4             (just now , 2)
# 5         (never before , 1)
# 6             (not here , 1)
# 7             (too long , 1)
# 8         (not possibly , 1)
# 9       (rather sharply , 1)
# 10            (up again , 1)
# 11          (alone here , 1)
# 12           (as nearly , 1)
# 13     (away altogether , 1)
# 14            (long ago , 1)
# 15         (slowly back , 1)
# 16         (well enough , 1)
# 17           (very soon , 1)
# 18            (not even , 1)
# 19            (now here , 1)
# 20          (enough yet , 1)
# 21         (about again , 1)
# 22            (not long , 1)
# 23          (back again , 1)
# 24        (as well wait , 1)
# 25           (nearly as , 1)
# 26           (very well , 1)
# 27           (very much , 1)
# 28              (not so , 1)
# 29           (even then , 1)
# 30        (very readily , 1)
# 31        (asleep again , 1)
# 32        (very angrily , 1)
# 33         (very humbly , 1)
# 34       (_there_ again , 1)
# 35  (_You'd_ better not , 1)
# 36        (angrily away , 1)
# 37        (then quietly , 1)
# 38     (down again very , 1)
# 39       (certainly not , 1)
# 40     (up very sulkily , 1)
# 41         (now hastily , 1)
# 42        (perhaps even , 1)

# %%
#we are ready to start preparing our csv file
#we first create a table using a pandas' dataframe
#to assign columns for the information extracted from each tweet
#namely title, author and country, along with and number of sentences stores before in our lists

df = pd.DataFrame(list(zip(total_pos, total_neg, total_neu)), 
                       columns = ['n_pos_sents', 'n_neg_sents', 'n_neu_sents'])

# %%
#printing the dataframe, to confirm everything is fine
df[:30]
# Out:
#     n_pos_sents  n_neg_sents  n_neu_sents
# 0             0            0            1
# 1             1            0            0
# 2             0            1            0
# 3             0            1            0
# 4             0            1            0
# 5             0            0            1
# 6             0            0            1
# 7             1            0            0
# 8             1            0            0
# 9             0            1            0
# 10            0            0            1
# 11            0            0            1
# 12            0            1            0
# 13            1            0            0
# 14            1            0            2
# 15            0            0            1
# 16            1            0            0
# 17            0            0            1
# 18            1            0            0
# 19            0            1            0
# 20            0            0            1
# 21            0            1            0
# 22            0            0            1
# 23            0            0            1
# 24            1            0            0
# 25            1            0            0
# 26            0            0            1
# 27            1            0            0
# 28            1            0            0
# 29            1            0            0

# %%
#we now finally save our table in a csv file

df.to_csv('alice1.csv', index = False)

# %%
#checking some of the ouptut: the first three sentences labeled as positive
pos_sent[:3]
# Out:
# ['Down the Rabbit-Hole',
#  'So she was considering in her own mind (as well as she could, for the',
#  'hot day made her feel very sleepy and stupid), whether the pleasure of']

# %%
#now the first 3 sentences labeled as negative
neg_sent[:3]
# Out:
# ['Alice was beginning to get very tired of sitting by her sister on the',
#  'bank, and of having nothing to do: once or twice she had peeped into',
#  'the book her sister was reading, but it had no pictures or']

# %%
#and finally the neutral ones
neu_sent[:3]
# Out:
# ['CHAPTER I.',
#  'conversations in it, and what is the use of a book,\x9d thought Alice',
#  'without pictures or conversations?\x9d']

# %%
#PLEASE OPEN THE NEWLY CREATED CSV FILE TO CHECK EVERYTHING IS FINE
#DO NOT FORGE TO EXPLAIN THE OUTPUTS IN YOUR REPORT

# %%
  
# creating the dataset
data = {'carroll_negative':588,'hemingway_negative':400,'carroll_neutral':1094, 'hemingway_neutral':1934, 'carroll_positive':1296,'hemingway_positive':3329}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='blue',
        width = 0.4)
 
plt.xlabel("counts")
plt.ylabel("sentiment")
plt.title("Sentiment Distribution")
plt.show()

# %%
# creating the dataset
data = {'carroll_negative':24,'hemingway_negative':9.8,'carroll_neutral':44, 'hemingway_neutral':47.7, 'carroll_positive':52,'hemingway_positive':82  }
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)
 
plt.xlabel("normalized_sentiment")
plt.ylabel("percentage (%)")
plt.title("Normalized Sentiment Distribution")
plt.show()

# %%
#creating emply lists to append the tweets to
pos_sent = []
neg_sent = []
neu_sent = []

#and total values of positive, negative or neutral tweets
#all these lists will end up as columns in our csv file, created later on
total_pos = []
total_neg = []
total_neu = []

#iterating over the test file of tweets we crated at the very beginning of the notebook
#PLEASE EDIT THE NUMBER OF DOCUMENTS AS MENTIONED ABOVE
for i in range(0, int(len(test_set['text'])/1)):
    #extracting the text
    sentences = nltk.sent_tokenize(test_set['text'][i])
    #opening the counter to add up positive, negative, or neutral according to predicted labels
    pos_count = 0
    neg_count = 0
    neu_count = 0
    #using our first classifier, the one trained with unigram features
    for sents in sentences:
        senti = classifier.classify(document_features(nltk.word_tokenize(sents), word_features))
        #adding items to the counter as they are classified
        if senti == 'positive':
            pos_sent.append(sents)
            pos_count += 1

        elif senti == 'negative':
            neg_sent.append(sents)
            neg_count += 1
    
        else:
            neu_sent.append(sents)
            neu_count += 1
    #appending the information from each sentence to the corresponding list       
    total_pos.append(pos_count)
    total_neg.append(neg_count)
    total_neu.append(neu_count)
